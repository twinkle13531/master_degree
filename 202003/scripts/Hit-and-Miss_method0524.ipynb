# %% [markdown]
# # Approximation of Pi Using Hit and Miss (Monte Carlo) Method

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10000

x = np.random.uniform(low=-1, high=1, size=[N, 1])
y = np.random.uniform(low=-1, high=1, size=[N, 1])

inside_bool = x**2+y**2 < 1

approx_pi = 4*np.sum(inside_bool)/N
print('Pi: {}, approximation : {}'.format(np.pi, approx_pi))

x_in = x[inside_bool]
y_in = y[inside_bool]

plt.figure(figsize=[5, 5])
plt.scatter(x, y, s=1) #s...サイズ（デフォルト20）
plt.scatter(x_in, y_in, color='r', s=1) #inside
plt.show()
# Out:
# Pi: 3.141592653589793, approximation : 3.1084

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/Users/shihosato/.pyenv/versions/miniconda3-4.7.12/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 


plt.close('all')
raw_image = cv2.imread('raw_3')
labeled_image = cv2.imread('labeled_3')


# blue = [0,0,255]  
red = [255,0,0]

inside_bool = (labeled_image[:,:,0] >=190  ) & ( labeled_image[:,:,1] <= 80) & (labeled_image[:,:,2] <= 80 )
inside_index = np.where(inside_bool ==1)
print(inside_index)
mask = np.zeros(labeled_image.shape[0:2])
print(raw_image.shape[0:2])
mask[inside_bool] = 255
raw_image[inside_index[0],inside_index[1],:] = [255,0,0]
plt.imshow(raw_image)
plt.show()
# Out:
# ---------------------------------------------------------------------
# ModuleNotFoundError                 Traceback (most recent call last)
# <ipython-input-6-c112754fbc28> in <module>
#       1 import numpy as np
# ----> 2 import cv2
#       3 import matplotlib.pyplot as plt
#       4
#       5
#
# ModuleNotFoundError: No module named 'cv2'
