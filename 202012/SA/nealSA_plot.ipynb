# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/SA

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import SA_exact_test_functions as net
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt
import statistics
import time

# %%
num_reads = 10000

# %% [markdown]
# ## SA

# %%
##2021-01-14 46bitだけもう一回
path = '../input/ost{}.csv'.format(bit)
df = pd.read_csv(path, sep=',')
res, elapsed_time = net.make_res_data(df, num_reads)
valid_y_info_dic = net.find_valid_y(res)
rvd = net.SA_res_valid_dic(df, res, valid_y_info_dic, num_reads)

path = '{}bit/nealSA_{}bit_10000numreads.png'.format(bit, num, bit, num)
t_dic = rvd.y_num_hist(path)

output_path = '{}bit/SA_{}bit_10000_p_value_transition.png'.format(bit, num, bit, num)
valid_y_list, p_dic = rvd.p_value_transition(output_path)

plot_path = '{}bit/SA_{}bit_10000_occurence_hist.png'.format(bit, num, bit, num)
occurrence_list = rvd.occurrence_hist(plot_path)

path = '{}bit/SA_{}bit_10000_num_y_transition.png'.format(bit, num, bit, num)
time_list = net.num_y_transition_nodup(df, num_reads, path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c93e30fe6301> in <module>
#      18 time_list = net.num_y_transition_nodup(df, num_reads, path)
#      19
# ---> 20 print('46bit SA p_value = {}'.format(rvd.calc_p_value(self)))
#
# NameError: name 'self' is not defined

# %%
print('46bit SA p_value = {}'.format(rvd.calc_p_value()))
# Out:
# 46bit SA p_value = 0.036692397166120334

# %%
print('46bit SA calculate_time = {}'.format(elapsed_time))
# Out:
# 46bit SA calculate_time = 12.676482200622559

# %%
print('46bit num_sample = {}'.format(len(valid_y_info_dic)))
# Out:
# 46bit num_sample = 9457

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    for num in [0]:
        path = '../input/ost{}_{}.csv'.format(bit, num)
        df = pd.read_csv(path, sep=',')
        res = net.make_res_data(df, num_reads)
        valid_y_info_dic = net.find_valid_y(res)
        rvd = net.SA_res_valid_dic(df, res, valid_y_info_dic, num_reads)

        path = '{}bit/{}/nealSA_{}bit_{}_10000numreads.png'.format(bit, num, bit, num)
        t_dic = rvd.y_num_hist(path)

        output_path = '{}bit/{}/SA_{}bit_{}_10000_p_value_transition.png'.format(bit, num, bit, num)
        valid_y_list, p_dic = rvd.p_value_transition(output_path)

        plot_path = '{}bit/{}/SA_{}bit_{}_10000_occurence_hist.png'.format(bit, num, bit, num)
        occurrence_list = rvd.occurrence_hist(plot_path)

        path = '{}bit/{}/SA_{}bit_{}_10000_num_y_transition.png'.format(bit, num, bit, num)
        time_list = net.num_y_transition_nodup(df, num_reads, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-d9ecb6bd7942> in <module>
#       2     for num in [0]:
#       3         path = '../input/ost{}_{}.csv'.format(bit, num)
# ----> 4         df = pd.read_csv(path, sep=',')
#       5         res = net.make_res_data(df, num_reads)
#       6         valid_y_info_dic = net.find_valid_y(res)
#
# ...

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    for num in [0, 1, 2, 3, 4]:
        path = '../input/ost{}_{}.csv'.format(bit, num)
        df = pd.read_csv(path, sep=',')
        res = net.make_res_data(df, num_reads)
        valid_y_info_dic = net.find_valid_y(res)
        rvd = net.SA_res_valid_dic(df, res, valid_y_info_dic, num_reads)

        path = '{}bit/{}/nealSA_{}bit_{}_10000numreads.png'.format(bit, num, bit, num)
        t_dic = rvd.y_num_hist(path)

        output_path = '{}bit/{}/SA_{}bit_{}_10000_p_value_transition.png'.format(bit, num, bit, num)
        valid_y_list, p_dic = rvd.p_value_transition(output_path)

        plot_path = '{}bit/{}/SA_{}bit_{}_10000_occurence_hist.png'.format(bit, num, bit, num)
        occurrence_list = rvd.occurrence_hist(plot_path)

        path = '{}bit/{}/SA_{}bit_{}_10000_num_y_transition.png'.format(bit, num, bit, num)
        time_list = net.num_y_transition_nodup(df, num_reads, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-35463697ccc9> in <module>
#       2     for num in [0, 1, 2, 3, 4]:
#       3         path = '../input/ost{}_{}.csv'.format(bit, num)
# ----> 4         df = pd.read_csv(path, sep=',')
#       5         res = net.make_res_data(df, num_reads)
#       6         valid_y_info_dic = net.find_valid_y(res)
#
# ...
