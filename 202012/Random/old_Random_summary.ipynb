# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/Random

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random_exact_test_functions as ret
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt

# %%
num_reads=10000

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            print(bit, num, t_list)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        print(bit, t_list)
# Out:
# 20 0 [11  8  9  5]
# 20 1 [12  8  5  3]
# 20 2 [13  8  6  3]
# 20 3 [13  7  5  3]
# 20 4 [12  8 10  5]
# 25 0 [17 10  7  9]
# 25 1 [20 13 11  6]
# 25 2 [12  9  8  8]
# 25 3 [17 11  9  9]
# 25 4 [17 10  8  7]
# 30 0 [21 12 12  6]
# 30 1 [18 10 11  9]
# 30 2 [19 12 10  7]
# 30 3 [17 11 11  9]
# 30 4 [19 13 10  8]
# 35 0 [21 13 13  7]
# 35 1 [22 15 11  9]
# 35 2 [23 15 11 10]
# 35 3 [22 15 14  9]
# 35 4 [23 15 11 10]
# 40 0 [25 16 13  9]
# 40 1 [26 18 15 12]
# 40 2 [25 16 14 10]
# 40 3 [25 16 14  9]
# 40 4 [26 17 16 12]
# 46 [29 19 16 12]

# %%
t1_dic = {}
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        t1_dic[bit] = []
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            t1_dic[bit].append(t_list[1])
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        t1_dic[46] = t_list[1]
t1_dic
# Out:
# {20: [8, 8, 8, 7, 8],
#  25: [10, 13, 9, 11, 10],
#  30: [12, 10, 12, 11, 13],
#  35: [13, 15, 15, 15, 15],
#  40: [16, 18, 16, 16, 17],
#  46: 19}

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
            if len(valid_y_dic) >0:
                rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
                plot_path = '{}bit/{}/Random_{}bit_{}_10000_occurence_hist.png'.format(bit, num, bit, num)
                rm.occurrence_hist(plot_path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
        if len(valid_y_dic) >0:
            rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
            plot_path = '{}bit/Random_{}bit_10000_occurence_hist.png'.format(bit, bit)
            rm.occurrence_hist(plot_path)

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
            if len(valid_y_dic) >0:
                rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
                plot_path = '{}bit/{}/Random_{}bit_{}_10000_y_num_t1.png'.format(bit, num, bit, num)
                t_tic = rm.y_num_t1_hist(plot_path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
        if len(valid_y_dic) >0:
            rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
            plot_path = '{}bit/Random_{}bit_10000_y_num_t1.png'.format(bit, bit)
            t_tic = rm.y_num_t1_hist(plot_path)

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
            if len(valid_y_dic) >0:
                rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
                output_path = '{}bit/{}/Random_{}bit_{}_10000_p_value_transition.png'.format(bit, num, bit, num)
                p_dic = rm.p_value_transition(output_path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
        if len(valid_y_dic) >0:
            rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
            output_path = '{}bit/Random_{}bit_10000_p_value_transition.png'.format(bit, bit)
            p_dic = rm.p_value_transition(output_path)

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
            if len(valid_y_dic) >0:
                rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
                path = '{}bit/{}/Random_{}bit_{}_10000_time_num_y_transition.png'.format(bit, num, bit, num)
                valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_dic, calculation_time = ret.find_valid_y(df, num_reads)
        if len(valid_y_dic) >0:
            rm = ret.Random_method(df, valid_y_dic, num_reads, t_list)
            path = '{}bit/Random_{}bit_10000_time_num_y_transition.png'.format(bit, bit)
            valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)
