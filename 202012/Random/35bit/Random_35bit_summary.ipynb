# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/Random/35bit

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append(os.path.join('..'))

# %%
import random_exact_test_functions as ret
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt

# %%
bit = 35

# %%
num_reads=10000

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
    plot_path = '{}/Random_{}bit_{}_10000_y_num_t1'.format(num, bit, num)
    t_tic = rm.y_num_t1_hist(plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
    output_path = '{}/Random_{}bit_{}_10000_p_value_transition'.format(num, bit, num)
    p_dic = rm.p_value_transition(output_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
    path = '{}/Random_{}bit_{}_10000_time_num_y_transition'.format(num, bit, num)
    valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)

# %%
y_num_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    y_num_list.append(valid_y_num)
    print('number of valid y of {}bit_{} data is {}'.format(bit, num, y_num_list[-1]))
print('mean number of valid y of {}bit data is {}'.format(bit, sum(y_num_list)/5))
# Out:
# number of valid y of 35bit_0 data is 0
# number of valid y of 35bit_1 data is 3
# number of valid y of 35bit_2 data is 0
# number of valid y of 35bit_3 data is 0
# number of valid y of 35bit_4 data is 0
# mean number of valid y of 35bit data is 0.6

# %%
p_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
    p_list.append(rm.p_value())
    print('p value of {}bit_{} data is {}'.format(bit, num, p_list[-1]))
# Out:
# p value of 35bit_0 data is can't calucurate p value
# p value of 35bit_1 data is 0.16666666666666666
# p value of 35bit_2 data is 0.0
# p value of 35bit_3 data is 0.0
# p value of 35bit_4 data is can't calucurate p value

# %%
print('mean p value of {}bit data is {}'.format(bit, 0.16666666666666666/3))
# Out:
# mean p value of 35bit data is 0.05555555555555555

# %%
time_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    loop = 10
    result = timeit.timeit('ret.find_valid_y(df, num_reads)', globals=globals(), number=loop)
    time_list.append(result/loop)
    print('calucuration time of {}bit_{} data is {}'.format(bit, num, time_list[-1]))
print('mean calucuration time of {}bit data is {}'.format(bit, sum(time_list)/5))
# Out:
# calucuration time of 35bit_0 data is 0.12113536419999989
# calucuration time of 35bit_1 data is 0.0989764326999996
# calucuration time of 35bit_2 data is 0.0983525102999998
# calucuration time of 35bit_3 data is 0.13848083689999982
# calucuration time of 35bit_4 data is 0.08333131019999981
# mean calucuration time of 35bit data is 0.10805529085999979
