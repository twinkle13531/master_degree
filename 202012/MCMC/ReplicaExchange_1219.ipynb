# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/MCMC

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import ReplicaExchange_1219 as rmcmc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
import time

# %%
## trial
bit, num = 20, 3
path = '../input/ost{}_{}.csv'.format(bit, num)
df = pd.read_csv(path, sep=',')
#t_list = rmcmc.calc_marginals(df)
MCMC_step = 10000
MCMC_step_each = 5
Max_temper = 100

# %%
#repmcmc = rmcmc.make_variables(df, Max_temper, MCMC_step, MCMC_step_each)

# %%
T = 100
#E, y_list = repmcmc.Montecarlo(T)
valid_y_dic = repmcmc.mcmc_find_valid_y(T)

# %%
valid_y_dic
# Out:
# {(1, 1, 0, 0, 1, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 1, 1, 0, 0, 1): 10001}

# %%
print(df['Y'].T)
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     1
# 6     1
# 7     1
# 8     1
# 9     0
# 10    1
# 11    1
# 12    1
# 13    0
# 14    0
# 15    1
# 16    1
# 17    0
# 18    0
# 19    1
# Name: Y, dtype: int64

# %%
MCMC_step = 100
MCMC_step_each = 5
Max_temper = 100#10000num_readsとおなじになるのでは、計算がおわってくれるのでは
repmcmc = rmcmc.make_variables(df, Max_temper, MCMC_step, MCMC_step_each)
valid_y_dic = repmcmc.replica_mcmc_find_valid_y()
# Out:
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here0
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# here1
# ...

# %%
valid_y_dic
# Out:
# {(1, 1, 0, 0, 1, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 1, 1, 0, 0, 1): 10001}
