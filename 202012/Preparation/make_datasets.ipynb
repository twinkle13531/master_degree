# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/scripts/trials/Preparation

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import sys, os
sys.path.append(os.path.join('..', '..', 'functions'))

# %%
import ost_datasets
import pandas as pd
import numpy as np

# %%
print(ost_datasets.__file__)
# Out:
# ../../functions/ost_datasets.py

# %%
for num_sample in [20, 25, 30, 35, 40]:
    for version_num in [1, 2, 3, 4]:
        ost_datasets.make_ost_num_df(num_sample, version_num)

# %%
#check
ost25_1 = pd.read_csv('../../../input/ost25_1.csv')
ost25_1
# Out:
#     Y  LI  SEX  AOP
# 0   1   0    0    1
# 1   0   1    1    0
# 2   0   1    1    0
# 3   1   0    0    0
# 4   1   1    1    0
# 5   1   1    0    1
# 6   1   1    0    0
# 7   1   1    1    1
# 8   1   0    1    0
# 9   1   1    0    1
# 10  0   1    1    1
# 11  1   1    0    1
# 12  1   1    1    1
# 13  1   0    0    1
# 14  0   1    1    1
# 15  0   1    1    1
# 16  0   1    0    1
# 17  0   1    1    1
# 18  0   1    1    1
# 19  1   1    0    0
# 20  0   1    1    0
# 21  0   1    1    1
# 22  0   1    1    1
# 23  1   0    1    0
# 24  0   1    1    1
