# %%
library(UpSetR)

prot1 <- c("A", "B", "C", "E", "F", "G", "N")
prot2 <- c("A", "B", "E", "G", "I", "N")
prot3 <- c("A", "B", "E", "G", "J", "N")
prot4 <- c("C", "G", "I", "K", "L", "M")
data <- list(TF1 = prot1, TF2 = prot2, TF3 = prot3, TF4 = prot4)

upset(fromList(data), order.by = "freq")
# Out:
# plot without title

# %% [markdown]
# <img src="../images/UpSet_plot.png">

# %% [markdown]
# ↑はintervene https://asntech.shinyapps.io/intervene/ で作成した
