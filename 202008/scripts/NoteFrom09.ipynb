# %% [markdown]
# # 中間発表後
#
# ### input dataなどについて（2020/09/15）
# 骨肉腫のデータ（exact logistic regression論文に載っているデータ）：性別とAOPが交絡因子、LIとDFI3の関係を知りたい。
#
# 交絡因子を固定にして、snpを一つづつ入れてp値を計算していく。それを100万回とか(snpの種類分)繰り返す。
#
# d-waveは64bitまでしか入らない。
#
# テーブルの数え上げ問題にできるかな
#
# マルコフベースと比較
#
# マルコフベース（マルコフ基底）：個人情報を出さずに公開する、ということに応用可能。
#
# テーマをマルコフ基底への応用、とする？？
#
# ★=Tm:mは表
# 0=Tk :NP-hard
#
# 論文：ゲート型の量子アルゴリズムを使って：横地場だけの状態（最適解が求まる）から始めて、コスト関数を変えて、断熱計算。横地場でないものから始める（start pointを変える）。d-waveでは初期状態を変えることはできない。でもゲート型だとできる。なので、qaoaを試している。
#
# 量子アニーリングは特異点のような場所から始める（異常）
#
# QAとSAで比較すればいい？スピードだけ比較させる。
#
# 全探索と比較する？
#
# 興味：smart sampling
#
# ## 進捗会(2020/09/24)
# tableはすべて2進数にする。7→111
#
# tableベースorサンプルベース
#
# SA, QA
#
# 良い解を出そうするとしっかりとQAを使わないといけない。
#
# ストローマさん
#
# 64bit
#
# 問題が大きくなったときに：ネットワークアルゴリズムDT, マルコフ基底→MCMC
#
# SAをストローマにして、サンプルSAT
#
# all SAT, count SAT, sharp SAT
#
# SAとは計算時間の比較？→SAは早い。
#
# D-waveサンプラーを使う
#
#
# ## 勉強内容 (2020/09/24 - 2020/09/29)
# - 今週したのは：量子コンピューターの本を読む、論文読んでみたけど広がらない。
#
# ## 日記（2020/09/29）
# 何をしているのか、という問いに答えられない。
#
# ## 進捗会（2020/09/29）
# - 勉強する内容として正しい方向なのか確認したい。
#
# ## やる宣言（2020/09/29）
# - 理想：量子力学、量子コンピューター、量子統計学、sat
# - ネットワークアルゴリズム
#
# 4ti2, マルコフ基底
#
# QAでしたほうが速かったよ
#
# 実機の練習問題として、骨肉腫データneal→実機
#
# 量子統計力学：
#
# 格子基底を用いたマルコフ連鎖
#
# 「量子力学で統計検定を行う。」というコンセプト
