# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/4ti2/results/markov/30bit

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append(os.path.join('..', '..', '..', 'functions'))

# %%
import pandas as pd
import numpy as np
import markov_basis_make_samples as mbms

# %% [markdown]
# ### 30bit

# %%
bit = 30

# %% [markdown]
# ## random method

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('20bit_', num, ' data can make ', len(ms.random(10000)), 'samples using markov basis and random method')
# Out:
# 20bit_ 0  data can make  2965 samples using markov basis and random method
# 20bit_ 1  data can make  3970 samples using markov basis and random method
# 20bit_ 2  data can make  3373 samples using markov basis and random method
# 20bit_ 3  data can make  3293 samples using markov basis and random method
# 20bit_ 4  data can make  3268 samples using markov basis and random method

# %%
print('i knew that 20bit data can make ', (2960+3970+3373+3296+3268)/5, 'samples using markov basis and random method.')
# Out:
# i knew that 20bit data can make  3373.4 samples using markov basis and random method.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/random_10000_t_num".format(num)
    hist_dic = mbms.y_num_t1_hist(df, ms.random(10000), plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('p values is',mbms.p_value(df, ms.random(10000)) , 'when i use 20bit_', num, ' data markov basis and random method')
# Out:
# p values is 0.04008016032064128 when i use 20bit_ 0  data markov basis and random method
# p values is 0.01641382740611788 when i use 20bit_ 1  data markov basis and random method
# p values is 0.20064440538957234 when i use 20bit_ 2  data markov basis and random method
# p values is 0.10148298924105845 when i use 20bit_ 3  data markov basis and random method
# p values is 0.08375156838143036 when i use 20bit_ 4  data markov basis and random method

# %%
mean_p = (0.04008016032064128+0.01641382740611788+0.20064440538957234+0.10148298924105845+0.08375156838143036)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and random method.')
# Out:
# i knew that mean p values of 20bit dat is 0.08847459014776407 when i use markov basis and random method.

# %% [markdown]
# ## SA

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('20bit_', num, ' data can make ', len(valid_y), 'samples using markov basis and SA')
# Out:
# 20bit_ 0  data can make  1513 samples using markov basis and SA
# 20bit_ 1  data can make  1950 samples using markov basis and SA
# 20bit_ 2  data can make  1687 samples using markov basis and SA
# 20bit_ 3  data can make  1668 samples using markov basis and SA
# 20bit_ 4  data can make  1601 samples using markov basis and SA

# %%
print('i knew that 20bit data can make ', (1513+1950+1678+1668+1601)/5, 'samples using markov basis and SA.')
# Out:
# i knew that 20bit data can make  1682.0 samples using markov basis and SA.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/SA_10000_t_num".format(num)
    E_list, valid_y = ms.SA(10000)
    hist_dic = mbms.y_num_t1_hist(df, valid_y, plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('p values is',mbms.p_value(df, valid_y) , 'when i use 20bit_', num, ' data markov basis and SA')
# Out:
# p values is 0.046296296296296294 when i use 20bit_ 0  data markov basis and SA
# p values is 0.027972027972027972 when i use 20bit_ 1  data markov basis and SA
# p values is 0.13700966458214894 when i use 20bit_ 2  data markov basis and SA
# p values is 0.07830245068738792 when i use 20bit_ 3  data markov basis and SA
# p values is 0.12814224402207236 when i use 20bit_ 4  data markov basis and SA

# %%
mean_p = (0.046296296296296294+0.027972027972027972+0.13700966458214894+0.07830245068738792+0.12814224402207236)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and SA.')
# Out:
# i knew that mean p values of 20bit dat is 0.08354453671198671 when i use markov basis and SA.
