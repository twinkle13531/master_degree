# %%
# !pwd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append(os.path.join('..', '..', '..', 'functions'))

# %%
import pandas as pd
import numpy as np
import markov_basis_make_samples as mbms

# %% [markdown]
# ### 40bit

# %%
bit = 40

# %% [markdown]
# ## random method

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('20bit_', num, ' data can make ', len(ms.random(10000)), 'samples using markov basis and random method')
# Out:
# 20bit_ 0  data can make  3473 samples using markov basis and random method
# 20bit_ 1  data can make  3535 samples using markov basis and random method
# 20bit_ 2  data can make  3550 samples using markov basis and random method
# 20bit_ 3  data can make  3778 samples using markov basis and random method
# 20bit_ 4  data can make  3104 samples using markov basis and random method

# %%
print('i knew that 20bit data can make ', (3473+3535+3550+3778+3104)/5, 'samples using markov basis and random method.')
# Out:
# i knew that 20bit data can make  3488.0 samples using markov basis and random method.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/random_10000_t_num".format(num)
    hist_dic = mbms.y_num_t1_hist(df, ms.random(10000), plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('p values is',mbms.p_value(df, ms.random(10000)) , 'when i use 20bit_', num, ' data markov basis and random method')
# Out:
# p values is 0.0310122878876536 when i use 20bit_ 0  data markov basis and random method
# p values is 0.06463553530751709 when i use 20bit_ 1  data markov basis and random method
# p values is 0.0670045045045045 when i use 20bit_ 2  data markov basis and random method
# p values is 0.0797498045347928 when i use 20bit_ 3  data markov basis and random method
# p values is 0.06796747967479674 when i use 20bit_ 4  data markov basis and random method

# %%
mean_p = (0.0310122878876536 + 0.06463553530751709 + 0.0670045045045045 + 0.0797498045347928 + 0.06796747967479674)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and random method.')
# Out:
# i knew that mean p values of 20bit dat is 0.06207392238185294 when i use markov basis and random method.

# %% [markdown]
# ## SA

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('20bit_', num, ' data can make ', len(valid_y), 'samples using markov basis and SA')
# Out:
# 20bit_ 0  data can make  1648 samples using markov basis and SA
# 20bit_ 1  data can make  1854 samples using markov basis and SA
# 20bit_ 2  data can make  1706 samples using markov basis and SA
# 20bit_ 3  data can make  1900 samples using markov basis and SA
# 20bit_ 4  data can make  1509 samples using markov basis and SA

# %%
print('i knew that 20bit data can make ', (1648+1854+1706+1900+1509)/5, 'samples using markov basis and SA.')
# Out:
# i knew that 20bit data can make  1723.4 samples using markov basis and SA.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/SA_10000_t_num".format(num)
    E_list, valid_y = ms.SA(10000)
    hist_dic = mbms.y_num_t1_hist(df, valid_y, plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('p values is',mbms.p_value(df, valid_y) , 'when i use 20bit_', num, ' data markov basis and SA.')
# Out:
# p values is 0.04360298336201951 when i use 20bit_ 0  data markov basis and SA.
# p values is 0.04169046259280411 when i use 20bit_ 1  data markov basis and SA.
# p values is 0.03775680177679067 when i use 20bit_ 2  data markov basis and SA.
# p values is 0.12144702842377261 when i use 20bit_ 3  data markov basis and SA.
# p values is 0.05593536357986327 when i use 20bit_ 4  data markov basis and SA.

# %%
mean_p = (0.04360298336201951 + 0.04169046259280411 + 0.03775680177679067 + 0.12144702842377261 + 0.05593536357986327)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and SA.')
# Out:
# i knew that mean p values of 20bit dat is 0.060086527947050036 when i use markov basis and SA.
