# %% [markdown]
# # ウェブデータ処理１: ウェブスクレイピング
#
#
# ある特定のサイトからハイパーリンクが張られているページの情報をすべてダウンロードしたい場合や、
# 頻繁に更新されるサイトの情報を定期的にダウンロードしたい場合は、
# それを自動で行うプログラムを作成し、利用するのが効率的です。
# Web上の様々なサイトの情報を自動的に収集することをクロール（それを行うプログラムをクローラ）、
# また収集した情報を利用しやすい形に処理することまでを含めてスクレイピングと呼びます。
#
# ここでは、簡単なウェブスクレイピングについて学びたいと思います。
#
# なお、以下では実際に様々なWebサイトにアクセスします。
# **whileなどのループで短時間で同じサイトにアクセスしまくるのは絶対にやめましょう。**
#
# 1回きりのアクセスであれば、そのサイトをブラウザで開くのと同じですが、
# 例えばwhile文でループさせるなどして短時間内に大量のサイトにアクセスしてしまうと、
# DoS攻撃（Denial of Service attack：Webサーバやそれにつながる通信網に意図的に過剰な負荷をかけることで、
# サービス提供を阻害すること）とみなされて、そのサイトへのアクセスを遮断されます
# （それ以前に、そのサイトに迷惑をかけることになりますね）。
#
# クロールする際はループで同じ同じサーバにアクセスすることになりますが、そうする場合は、十分な時間間隔（サーバの規模にもよりますが30秒以上。小規模なサーバだとリソースも少ないので、それでも遮断されることがあります）をあけてアクセスするようにしてください。
# そうすると、当然一定期間内に集められる情報が少なくなりますが、そういうものだとあきらめてください。。。

# %% [markdown]
# ## 1. Webページの取得
#
# まず、URLを指定してWebページの情報を取得します。
# ここでは`requests`というモジュールを使用します。これはAnacondaではデフォルトでインストールされるパッケージです。
# アクセス先は東京大学のホームページとします。

# %%
import random
import requests

url = 'https://www.u-tokyo.ac.jp/ja/index.html'

res = requests.get(url)
res.encoding = res.apparent_encoding  # 文字コードを設定
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja">
#     <head>
#         <meta charset="UTF-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <title>東京大学</title>
#         <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=2,minimum-scale=1" user-scalable="yes">
#         <meta name="description" content="東京大学のオフィシャルサイトです。大学案内、学部・大学院等の紹介、研究活動・国際活動、入学案内等、東京大学の情報をご覧いただけます。">
#         <meta name="keywords" content="">
#         <meta name="copyright" content="(C)東京大学">
#
#         <link rel="shortcut icon" href="/content/100074614.ico">
#
#         <meta property="og:title" content="東京大学">
#         <meta property="og:site_name" content="東京大学">
#         <meta property="og:type" content="website">
#         <meta property="og:description" content="東京大学のオフィシャルサイトです。大学案内、学部・大学院等の紹介、研究活動・国際活動、入学案内等、東京大学の情報をご覧いただけます。">
#         <meta property="og:url" content="https://www.u-tokyo.ac.jp/ja/index.html">
#         <meta property="og:image" content="https://www.u-tokyo.ac.jp/content/400119944.jpg">
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:title" content="東京大学">
#         <meta name="twitter:description" content="東京大学のオフィシャルサイトです。大学案内、学部・大学院等の紹介、研究活動・国際活動、入学案内等、東京大学の情報をご覧いただけます。">
#         <meta name="twitter:image" content="https://www.u-tokyo.ac.jp/content/400119944.jpg">
#
#         <link href="https://fonts.googleapis.com/earlyaccess/notosansjapanese.css" rel="stylesheet" />
#         <link href="https://fonts.googleapis.com/css?family=Roboto:100,300,400,500,700" rel="stylesheet">
#
#         <link rel="stylesheet" href="/content/style.css">
#         <link rel="stylesheet" href="/aly.css">
#
#     </head>
#     <body class="utokyo_top">
#
#         <!-- .l-wrapper -->
#         <div class="l-wrapper">
#
# <noscript>東京大学ウェブサイトを正しく表示するにはJavaScriptが必要です。<br />ブラウザの設定をオンにしてからページをリロードしてください。</noscript>
#
#             <!-- HEADER -->
#             <header class="l-header">
#                 <div class="header-inner">
#
#                     <h1 class="l-header__logo"><a href="/ja/index.html"><img src="/content/400109180.jpg" alt="東京大学" class="u-img-responsive"></a></h1>
#
#                     <ul class="l-header__link">
#                         <li class="l-header__link-item l-header__link-item-01"><a href="#content">本文へ</a></li>
#                         <li class="l-header__link-item l-header__link-item-02"><a href="/ja/about/campus-guide/index.html">アクセス・キャンパスマップ</a></li>
#                         <li class="l-header__link-item l-header__link-item-03"><a href="/ja/general/contact.html">お問い合わせ</a></li>
#                         <li class="l-header__link-item l-header__link-item-04"><a href="http://utf.u-tokyo.ac.jp/index.html" target="_blank">寄附をお考えの方<img src="/content/100075725.png" alt="別ウィンドウで開く"></a></li>
#                     </ul>
#                     <div class="l-header__language">
#                         <a href="#" class="is-open"><span lang="en">Language</span></a>
#                         <ul class="l-header__language-list">
#                             <li><a href="/en/index.html"><span lang="en">English</span></a></li>
#                             <li><a href="/zh/index.html"><span lang="zh">中文</span></a></li>
#                             <li><a href="/ko/index.html"><span lang="ko">한국어</span></a></li>
#                         </ul>
#                     </div>
#                     <div class="l-header__form-box">
#                         <form method="get" action="/ja/search/index.html" name="searchHead" id="myForm">
#                             <div class="l-header__form-box-inner">
#                                 <input type="text" class="l-header__form" name="q" id="word" value="" title="サイト内検索">
#                                 <button type="submit" class="l-header__form-button" name="Submit" value="" onClick="document.searchHead.action='/ja/search/index.html'">サイト内検索</button>
#                             </div>
#                             <button type="submit" class="l-header__form-teacher" name="Submit" value="" onClick="document.searchHead.action='/focus/ja/people/'">教員検索</button>
#                         </form>
#                     </div>
#                 </div>
#             </header>
#             <!-- /HEADER -->
#
#
#             <!-- GNAV -->
#             <div class="l-gnav">
#                 <div class="nav-top-inner">
#                     <div class="l-gnav__top">
#                         <p class="l-gnav__home"><a href="/ja/index.html"><span lang="en">HOME</span></a></p>
#                         <a href="/focus/ja/index.html" class="l-gnav__focus"><img src="/content/100074616.jpg" alt="UTokyo FOCUS"></a>
#                     </div>
#                 </div>
#
#                 <nav>
#                     <div class="nav-bottom-inner">
#                         <ul class="l-gnav__list">
#                             <li class="l-gnav__item l-gnav__item-01">
#                                 <a href="/ja/about/index.html">大学案内</a>
#                                 <div class="p-sub-menu p-sub-menu-01">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/about/index.html#category1">大学概要</a></li>
#                                                     <li><a href="/ja/about/index.html#category2">キャンパス案内</a></li>
#                                                     <li><a href="/ja/about/president/b01.html">総長室から</a></li>
#                                                     <li><a href="/ja/about/index.html#category4">称号授与</a></li>
#                                                     <li><a href="/ja/about/index.html#category5">東京大学の歴史</a></li>
#                                                     <li><a href="/ja/about/index.html#category6">広報・刊行物</a></li>
#                                                     <li><a href="/ja/about/index.html#category7">情報公開</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/about/index.html#category8">公表事項</a></li>
#                                                     <li><a href="/ja/about/index.html#category9">東京大学の取り組み</a></li>
#                                                     <li><a href="/ja/about/index.html#category10">規則・コンプライアンス</a></li>
#                                                     <li><a href="/ja/about/index.html#category11">点検・評価</a></li>
#                                                     <li><a href="/ja/about/index.html#category12">キャンパス計画</a></li>
#                                                     <li><a href="/ja/about/index.html#category13">調達・契約</a></li>
#                                                     <li><a href="/ja/about/jobs/index.html">採用情報</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116151.png" alt="大学案内">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-02">
#                                 <a href="/ja/schools-orgs/index.html">学部・大学院等</a>
#                                 <div class="p-sub-menu p-sub-menu-02">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/schools-orgs/faculties/faculty.html">学部</a></li>
#                                                     <li><a href="/ja/schools-orgs/faculties/faculty.html">研究科</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/institutes.html">附置研究所</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/centers.html">全学センター</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/utias.html">国際高等研究所</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/interdisciplinary.html">学際融合研究施設</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/joint-use.html">全国共同利用施設</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/schools-orgs/centers/committee.html">機構等(総長室総括委員会設置)</a></li>
#                                                     <li><a href="/ja/schools-orgs/centers/integrate.html">連携研究機構</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116153.png" alt="学部・大学院等">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-03">
#                                 <a href="/ja/admissions/index.html">入学案内</a>
#                                 <div class="p-sub-menu p-sub-menu-03">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/admissions/index.html#category1">学部入学</a></li>
#                                                     <li><a href="/ja/admissions/graduate/e02_02.html">大学院入学・社会人入試</a></li>
#                                                     <li><a href="/ja/admissions/index.html#category3">入学料・授業料</a></li>
#                                                     <li><a href="http://www.u-tokyo.ac.jp/adm/inbound/ja/">海外から東大への留学</a></li>
#                                                     <li><a href="http://www.u-tokyo.ac.jp/adm/inbound/ja/">留学生支援</a></li>
#                                                     <li><a href="/ja/admissions/index.html#category6">統計資料</a></li>
#                                                     <li><a href="/ja/admissions/adm-data/e01_011.html">帰国子女・留学生について</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/admissions/adm-data/e01_02.html">入学者選抜方法等の概要</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116109.png" alt="入学案内">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-04">
#                                 <a href="/ja/students/index.html">教育・学生生活</a>
#                                 <div class="p-sub-menu p-sub-menu-04">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/students/index.html#category1">授業・履修</a></li>
#                                                     <li><a href="/ja/students/index.html#category2">特徴的な教育活動</a></li>
#                                                     <li><a href="/ja/students/index.html#category3">学籍・手続窓口</a></li>
#                                                     <li><a href="/ja/students/index.html#category4">情報サービス・保険</a></li>
#                                                     <li><a href="/ja/students/index.html#category5">授業料・奨学制度・宿舎等</a></li>
#                                                     <li><a href="/ja/students/index.html#category6">課外活動</a></li>
#                                                     <li><a href="/ja/students/index.html#category7">施設利用</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/students/index.html#category8">保健・進路・相談</a></li>
#                                                     <li><a href="/ja/students/index.html#category9">行事・シンボル</a></li>
#                                                     <li><a href="/ja/students/index.html#category10">構内交通・警備・環境</a></li>
#                                                     <li><a href="/ja/students/index.html#category11">東大から海外への留学</a></li>
#                                                     <li><a href="/ja/students/index.html#category12">参考情報</a></li>
#                                                     <li><a href="/ja/students/index.html#category13">規則等</a></li>
#                                                     <li><a href="/ja/students/index.html#category14">教育統計資料</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116116.png" alt="教育・学生生活">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-05">
#                                 <a href="/ja/research/index.html">研究活動</a>
#                                 <div class="p-sub-menu p-sub-menu-05">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/research/index.html#category1">研究組織・プロジェクト</a></li>
#                                                     <li><a href="/ja/research/index.html#category2">制度・統計資料</a></li>
#                                                     <li><a href="/ja/research/index.html#category3">研究倫理・生命倫理</a></li>
#                                                     <li><a href="/ja/research/index.html#category4">安全保障輸出管理</a></li>
#                                                     <li><a href="/ja/research/index.html#category5">研究成果・書籍</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116161.png" alt="研究活動">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-06">
#                                 <a href="/ja/society/index.html">社会連携</a>
#                                 <div class="p-sub-menu p-sub-menu-06">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/society/index.html#category1">社会とともに歩む東京大学</a></li>
#                                                     <li><a href="/ja/society/index.html#category2">研究成果の還元</a></li>
#                                                     <li><a href="/ja/society/index.html#category3">一般見学・公開講座案内</a></li>
#                                                     <li><a href="/ja/society/index.html#category4">社会人向け教育</a></li>
#                                                     <li><a href="/ja/society/index.html#category5">地域等との連携</a></li>
#                                                     <li><a href="/ja/society/index.html#category6">東京大学への支援</a></li>
#                                                     <li><a href="/ja/society/index.html#category7">東京大学からの支援</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/society/index.html#category8">関連施設</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116132.png" alt="社会連携">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-07">
#                                 <a href="/ja/industry-collab/index.html">産学連携</a>
#                                 <div class="p-sub-menu p-sub-menu-07">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/industry-collab/index.html#category1">東京大学の産学連携</a></li>
#                                                     <li><a href="/ja/industry-collab/index.html#category2">産学協創推進本部組織構成</a></li>
#                                                     <li><a href="/ja/industry-collab/index.html#category3">関連組織等(外部サイト)</a></li>
#                                                     <li><a href="/ja/industry-collab/index.html#category4">制度・様式</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116137.png" alt="産学連携">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-08">
#                                 <a href="/ja/intl-activities/index.html">国際交流</a>
#                                 <div class="p-sub-menu p-sub-menu-08">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/intl-activities/index.html#category1">グローバル化に向けた取組み</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category2">海外大学との交流</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category3">東大生の海外留学等</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category4">留学生・外国人研究者サポート</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category5">組織</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category6">海外拠点</a></li>
#                                                     <li><a href="/ja/intl-activities/index.html#category7">統計資料</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/intl-activities/index.html#category8">学内限定コンテンツ</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116078.png" alt="国際交流">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                             <li class="l-gnav__item l-gnav__item-09">
#                                 <a href="/ja/alumni/index.html">卒業生</a>
#                                 <div class="p-sub-menu p-sub-menu-09">
#                                     <div class="p-sub-menu__inner">
#                                         <div class="l-row l-gutter-50">
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/alumni/index.html#category1">学ぶ</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category2">学生を支援する</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category3">集う</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category4">貢献する</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category5">TFT(東京大学オンラインコミュニティ)</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category6">広報</a></li>
#                                                     <li><a href="/ja/alumni/index.html#category7">東京大学校友会</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <ul class="p-sub-menu__list">
#                                                     <li><a href="/ja/alumni/index.html#category8">サービス＆ベネフィット</a></li>
#                                                 </ul>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-4">
#                                                 <figure class="p-sub-menu_img">
#                                                     <img src="/content/100116096.png" alt="卒業生">
#                                                 </figure>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </li>
#                         </ul>
#                     </div>
#                 </nav>
#
#             </div>
#             <!-- /GNAV -->
#
#             <p class="l-gnav__trigger"></p>
#
#             <div class="l-gnav-sub-wrapper">
#                 <div class="l-gnav-sub-inner">
#
#                     <div class="l-gnav-sub__form-box">
#                         <div class="l-gnav-sub__form-box-inner">
#                             <form method="get" action="/ja/search/index.html" name="searchHeadSpMenu" id="myFormSpMenu">
#                                 <input type="text" class="l-gnav-sub__form" name="q" id="wordSpMenu" value="" title="サイト内検索">
#                                 <button type="submit" class="l-gnav-sub__form-button" name="Submit" value="" onClick="document.searchHeadSpMenu.action='/ja/search/index.html'">サイト内検索</button>
#                             </form>
#                         </div>
#                         <p class="l-gnav-sub__form-teacher"><a href="/focus/ja/people/">教員検索</a></p>
#                     </div>
#
#                     <nav class="l-gnav-sub">
#                         <ul class="l-gnav-sub__list">
#                             <li class="l-gnav-sub__item"><a href="/ja/index.html"><span lang="en">HOME</span></a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/about/index.html">大学案内</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/schools-orgs/index.html">学部・大学院等</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/admissions/index.html">入学案内</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/students/index.html">教育・学生生活</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/research/index.html">研究活動</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/society/index.html">社会連携</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/industry-collab/index.html">産学連携</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/intl-activities/index.html">国際交流</a></li>
#                             <li class="l-gnav-sub__item"><a href="/ja/alumni/index.html">卒業生</a></li>
#                         </ul>
#                     </nav>
#                     <p class="l-gnav-sub__focus-title"><a href="/focus/ja/index.html" lang="en">UTokyo <span>FOCUS</span></a></p>
#                     <ul class="l-gnav-sub__focus-list">
#                         <li class="l-gnav-sub__focus-list-item"><a href="/ja/about/campus-guide/index.html">アクセス・キャンパスマップ</a></li>
#                         <li class="l-gnav-sub__focus-list-item"><a href="http://utf.u-tokyo.ac.jp/index.html" target="_blank">寄付をお考えの方<img src="/content/100074653.png" alt="別ウィンドウで開く"></a></li>
#                         <li class="l-gnav-sub__focus-list-item"><a href="/ja/general/contact.html">お問い合わせ</a></li>
#                     </ul>
#                 </div>
#             </div>
#
#             <div class="l-gnav-language-wrapper">
#                 <ul class="l-gnav-language__list">
#                     <li class="l-gnav-language__item"><a href="/en/index.html"><span lang="en">English</span></a></li>
#                     <li class="l-gnav-language__item"><a href="/zh/index.html"><span lang="zh">中文</span></a></li>
#                     <li class="l-gnav-language__item"><a href="/ko/index.html"><span lang="ko">한국어</span></a></li>
#                 </ul>
#             </div>
#
#
#             <!-- MAIN -->
#             <main class="l-main">
#
#                 <!-- #content -->
#                 <div id="content" class="c-content">
#
#                     <div class="p-top-main u-pc-block">
#
#                         <div class="p-slider-pc">
#                             <div><a href="https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA"><img src="/content/400119944.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">FSIプロジェクトシリーズ<br>国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/focus/ja/features/voices069.html"><img src="/content/400119832.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">UTOKYO VOICES<br>光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/opendays/index.html"><img src="/content/400119155.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">「高校生のためのオープンキャンパス2019」<br>2019年8月7日(水)･ 8日(木)に実施します。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/focus/ja/features/z0508_00132.html"><img src="/content/400118046.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">UTokyo FOCUS<br>足立区と東大の｢おいしい｣関係</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894" target="_blank"><img src="/content/400117191.jpg" alt="別ウィンドウで開く">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">キミの東大<br>薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/ja/about/public-relations/tansei.html"><img src="/content/400110613.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">東京大学広報誌<br>「淡青」38号</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="http://www.tc.u-tokyo.ac.jp/ja/" target="_blank"><img src="/content/400109797.jpg" alt="別ウィンドウで開く">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">東京カレッジ<br>世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。</div>
#                                 </div>
#                             </a></div>
#                         </div>
#
#                         <div class="p-slider-navigation">
#                             <div class="p-slider-pager"></div>
#                         </div>
#
#                     </div>
#
#                     <div class="p-top-main u-sp-block">
#
#                         <div class="p-slider-sp">
#                             <div><a href="https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA"><img src="/content/400119944.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">FSIプロジェクトシリーズ<br>国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/focus/ja/features/voices069.html"><img src="/content/400119832.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">UTOKYO VOICES<br>光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/opendays/index.html"><img src="/content/400119155.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">「高校生のためのオープンキャンパス2019」<br>2019年8月7日(水)･ 8日(木)に実施します。</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/focus/ja/features/z0508_00132.html"><img src="/content/400118046.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">UTokyo FOCUS<br>足立区と東大の｢おいしい｣関係</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894" target="_blank"><img src="/content/400117191.jpg" alt="別ウィンドウで開く">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">キミの東大<br>薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="/ja/about/public-relations/tansei.html"><img src="/content/400110613.jpg" alt="">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">東京大学広報誌<br>「淡青」38号</div>
#                                 </div>
#                             </a></div>
#                             <div><a href="http://www.tc.u-tokyo.ac.jp/ja/" target="_blank"><img src="/content/400109797.jpg" alt="別ウィンドウで開く">
#                                 <div class="p-slider-msg">
#                                     <div class="p-slider-msg-inner">東京カレッジ<br>世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。</div>
#                                 </div>
#                             </a></div>
#                         </div>
#
#                         <div class="p-slider-navigation">
#                             <div class="p-slider-pager"></div>
#                         </div>
#
#                     </div>
#
#                     <div class="p-top-important-notices">
#                         <p class="p-top-important-notices-title">重要なお知らせ</p>
# <ul>
# 	<li><a href="/focus/ja/articles/z1201_00001.html"><span>2019年6月14日</span>【注意喚起】東京大学を装った迷惑メール（なりすまし）にご注意ください（本部情報戦略課）</a></li>
# 	<li><a href="/ja/admissions/undergraduate/e01_admission_method_05.html"><span>2019年3月8日</span>2021年度入学者選抜（2020年度実施）に関する予告について（本部入試課）</a></li>
# 	<li><a href="/ja/admissions/undergraduate/e01_05.html"><span>2019年3月8日</span>平成31年度前期日程試験における試験問題及び解答等の公表について（本部入試課）</a></li>
# 	<li><a href="/focus/ja/articles/z0603_00005.html"><span>2018年9月10日</span>平成30年8月30日からの大雨ならびに平成30年北海道胆振東部地震で被災した世帯の学生の皆さんへ (本部奨学厚生課)</a></li>
# 	<li><a href="/focus/ja/articles/z0603_00003.html"><span>2018年7月10日</span>平成30年台風第7号及び前線等に伴う大雨で被災した世帯の学生の皆さんへ (本部奨学厚生課)</a></li>
# </ul>
#
#                     </div>
#
#
#                     <div class="c-section p-top-focus-events">
#                         <div class="c-section__ineer">
#
#                             <div class="p-top-focus">
#                                 <div class="l-row l-gutter-40">
#                                     <div class="l-col-xs-12 l-col-sm-3">
#                                         <div class="p-top-focus__item p-top-focus__item-first">
#                                             <figure class="p-top-focus__image-box">
#                                                 <img src="/content/400088131.png" alt="">
#                                             </figure>
#                                             <p class="p-top-focus__item-title-text">話題の記事やイベントなど<br>東京大学の情報を<br>幅広く発信します</p>
#                                             <p class="p-top-focus__item-title-button"><a href="/focus/ja/index.html">UTokyo FOCUSへ</a></p>
#                                         </div>
#                                     </div>
#                                 <div class="l-col-xs-12 l-col-sm-3">
#                                     <div class="p-top-focus__item">
#                                         <a href="/focus/ja/features/fsi013.html">
#                                             <figure class="p-top-focus__image-box">
#                                                 <img src="/content/400117278.jpg" alt="">
#                                             </figure>
#                                             <p class="p-top-focus__item-text">宇宙用から、地球用へ</p>
#                                             <p class="p-top-focus__item-date">2019年7月15日</p>
#                                             <p class="p-top-focus__item-tag" lang="en">科学と技術</p>
#                                         </a>
#                                     </div>
#                                 </div>
#                                 <div class="l-col-xs-12 l-col-sm-3">
#                                     <div class="p-top-focus__item">
#                                         <a href="/focus/ja/features/voices069.html">
#                                             <figure class="p-top-focus__image-box">
#                                                 <img src="/content/400119211.jpg" alt="">
#                                             </figure>
#                                             <p class="p-top-focus__item-text">光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。...</p>
#                                             <p class="p-top-focus__item-date">2019年7月11日</p>
#                                             <p class="p-top-focus__item-tag" lang="en">UTOKYO VOICES</p>
#                                         </a>
#                                     </div>
#                                 </div>
#                                 <div class="l-col-xs-12 l-col-sm-3">
#                                     <div class="p-top-focus__item">
#                                         <a href="/focus/ja/articles/z0102_00075.html">
#                                             <figure class="p-top-focus__image-box">
#                                                 <img src="/content/100074697.jpg" alt="">
#                                             </figure>
#                                             <p class="p-top-focus__item-text">「2019年度厚生労働省臨床研究総合促進事業　治験・倫理審査委員会委員...</p>
#                                             <p class="p-top-focus__item-date">2019年7月11日</p>
#                                             <p class="p-top-focus__item-tag" lang="en">お知らせ</p>
#                                         </a>
#                                     </div>
#                                 </div>
#
#                                 </div>
#                             </div>
#
#                             <div class="p-top-events">
#                                 <div class="c-section__title-wrap"><p class="c-section__title" lang="en">NEW <span>EVENTS</span></p></div>
#                                 <div class="l-row l-gutter-40">
#                                     <div class="l-col-xs-12 l-col-sm-4">
#                                         <div class="p-top-events__item">
#                                             <a href="/focus/ja/events/z0106_00007.html">
#                                                 <span><img src="/content/100074625.png" alt=""></span>
#                                                 <div class="p-top-events__item-body">
#                                                     <p class="p-top-events__item-date">2019年8月24日</p>
#                                                     <p class="p-top-events__item-title">第104回小石川植物園市民セミナーのご案内</p>
#                                                 </div>
#                                             </a>
#                                         </div>
#                                     </div>
#                                     <div class="l-col-xs-12 l-col-sm-4">
#                                         <div class="p-top-events__item">
#                                             <a href="/focus/ja/events/z0202_00011.html">
#                                                 <span><img src="/content/100074624.png" alt=""></span>
#                                                 <div class="p-top-events__item-body">
#                                                     <p class="p-top-events__item-date">2019年7月23日&#8212;2019年7月26日</p>
#                                                     <p class="p-top-events__item-title">地震研究所×北京大学地球空間科学学院「第1回固体地球科学サマースクール"Dyna...</p>
#                                                 </div>
#                                             </a>
#                                         </div>
#                                     </div>
#                                     <div class="l-col-xs-12 l-col-sm-4">
#                                         <div class="p-top-events__item">
#                                             <a href="/focus/ja/events/z0211_00065.html">
#                                                 <span><img src="/content/100074625.png" alt=""></span>
#                                                 <div class="p-top-events__item-body">
#                                                     <p class="p-top-events__item-date">2019年7月18日</p>
#                                                     <p class="p-top-events__item-title">RCAST Security Seminar #16 米中貿易戦争と日本</p>
#                                                 </div>
#                                             </a>
#                                         </div>
#                                     </div>
#
#                                 </div>
#                                 <p class="p-top-events__calendar-link"><a href="/focus/ja/events">イベントカレンダー</a></p>
#                             </div>
#
#                         </div>
#                     </div>
#
#                     <div class="c-section p-top-highlights-updates">
#                         <div class="c-section__ineer">
#
#                             <div class="l-row l-gutter-40">
#
#
#                                 <div class="l-col-xs-12 l-col-sm-6">
#                                     <div class="p-top-highlights">
#                                         <div class="c-section__title-wrap"><p class="c-section__title" lang="en">HIGHLIGHTS</p></div>
#                                         <div class="l-row l-gutter-40" id="p-top-highlights-wrap">
#
#                                             <div class="l-col-xs-6 l-col-sm-6">
#                                                 <div class="p-top-highlights__item">
#                                                     <a href="/adm/fsi/ja/index.html">
#                                                         <figure><img src="/content/400094844.png" alt=""></figure>
#                                                         <p class="p-top-highlights__item-title">未来社会協創推進本部</p>
#                                                     </a>
#                                                 </div>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-6">
#                                                 <div class="p-top-highlights__item">
#                                                     <a href="/ja/about/president/index.html">
#                                                         <figure><img src="/content/400094843.jpg" alt=""></figure>
#                                                         <p class="p-top-highlights__item-title">総長談論</p>
#                                                     </a>
#                                                 </div>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-6">
#                                                 <div class="p-top-highlights__item">
#                                                     <a href="/ja/admissions/undergraduate/e01_26.html">
#                                                         <figure><img src="/content/400088087.jpg" alt=""></figure>
#                                                         <p class="p-top-highlights__item-title">東京大学 推薦入試</p>
#                                                     </a>
#                                                 </div>
#                                             </div>
#                                             <div class="l-col-xs-6 l-col-sm-6">
#                                                 <div class="p-top-highlights__item">
#                                                     <a href="/ja/about/public-relations/IRIR.html">
#                                                         <figure><img src="/content/400101527.jpg" alt=""></figure>
#                                                         <p class="p-top-highlights__item-title">統合報告書2018</p>
#                                                     </a>
#                                                 </div>
#                                             </div>
#
#                                         </div>
#
#                                     </div>
#                                 </div>
#
#                                 <div class="l-col-xs-12 l-col-sm-6">
#                                     <div class="p-top-updates">
#                                        <div class="c-section__title-wrap"><p class="c-section__title" lang="en">PAGE <span>UPDATES</span></p></div>
#
#                                         <ul class="p-top-updates__list">
# <li class="p-top-updates__list-item">
# <a href="/ja/admissions/undergraduate/e01_07_14.html">
# <p class="p-top-updates__list-date">2019年7月12日</p>
# <p class="p-top-updates__list-title">主要大学説明会2019</p>
# </a>
# </li>
# <li class="p-top-updates__list-item">
# <a href="/adm/fsi/ja/symposium.html">
# <p class="p-top-updates__list-date">2019年7月12日</p>
# <p class="p-top-updates__list-title">FSIシンポジウム・シリーズ</p>
# </a>
# </li>
# <li class="p-top-updates__list-item">
# <a href="/ja/alumni/support-programs/mentar.html">
# <p class="p-top-updates__list-date">2019年7月4日</p>
# <p class="p-top-updates__list-title">卒業生によるキャリア支援</p>
# </a>
# </li>
# <li class="p-top-updates__list-item">
# <a href="/ja/about/public-relations/kouhou.html">
# ...
#                                         <a href="http://utssi.c.u-tokyo.ac.jp/index.html" target="_blank" class="p-top-intiatives__item-image">
#                                             <p class="p-top-intiatives__item-title">スポーツ先端科学<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></p>
#                                             <figure><img src="/content/400088094.jpg" alt=""></figure>
#                                         </a>
#                                     </div>
#                                 </div>
#                                 <div class="l-col-xs-6 l-col-sm-3 with-image">
#                                     <div class="p-top-intiatives__item">
#                                         <a href="http://kyodo-sankaku.u-tokyo.ac.jp/index.html" target="_blank" class="p-top-intiatives__item-image">
#                                             <p class="p-top-intiatives__item-title">男女共同参画<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></p>
#                                             <figure><img src="/content/400106907.jpg" alt=""></figure>
#                                         </a>
#                                     </div>
#                                 </div>
#
#                                 <div class="l-col-xs-6 l-col-sm-3">
#                                     <div class="p-top-intiatives__item">
#                                         <a href="/ja/society/aid/info.html">
#                                             <p class="p-top-intiatives__item-title">東日本大震災<br>東京大学の対応</p>
#                                         </a>
#                                     </div>
#                                 </div>
#                                 <div class="l-col-xs-6 l-col-sm-3">
#                                     <div class="p-top-intiatives__item">
#                                         <a href="/ja/about/history/140ut.html">
#                                             <p class="p-top-intiatives__item-title">140周年創設記念事業</p>
#                                         </a>
#                                     </div>
#                                 </div>
#                             </div>
#
#                         </div>
#                     </div>
#
#
#                     <div class="c-section p-top-book-movie">
#                         <div class="c-section__ineer">
#
#                             <div class="c-section__title-wrap"><p class="c-section__title" lang="en">UTokyo <span>MEDIA</span></p></div>
#
#                             <div class="l-row l-gutter-40">
#
#                                 <div class="l-col-xs-12 l-col-sm-3">
#                                         <p class="p-top-book__title">新着書籍</p>
#                                         <a href="/biblioplaza/ja/D_00001.html"><div class="p-top-book">
#                                             <figure><img src="/content/400112267.jpg" alt="白い表紙にベージュの模様"></figure>
#                                             <div class="p-top-book__body">
#                                                 <p class="p-top-book__body-title">行政学講義</p>
#                                                 <p class="p-top-book__body-sub-title">金井 利之
# </p>
#                                                 <p class="p-top-book__body-text">本書は、一般読者向けに、日本の行政と官僚制を紹介するものである。タイトルは、「行政学講義」となってい...[続きを見る]</p>
#                                             </div>
#                                         </div></a>
#                                 </div>
#
#
# <div class="l-col-xs-12 l-col-sm-9">
# 	<div class="p-top-movie">
# 		<p class="p-top-movie__title">UTokyo FSI 未来社会協創 紹介ビデオ</p>
#
# 		<figure><a href="https://youtu.be/z6itIL3Gvy0" target="_blank"><img alt="Movie" src="/content/400115014.png"></a></figure>
# 	</div>
# </div>
#
#
#                             </div>
#                         </div>
#                     </div>
#
#                     <div class="c-section p-top-link">
#                         <div class="c-section__ineer">
#                             <div class="l-row l-gutter-40">
#
#                                 <div class="l-col-xs-12 l-col-sm-4">
#                                     <dl class="p-top-link__list">
#                                         <dt>東京大学附属施設</dt>
#                                         <dd>
#                                             <ul>
#                                     <li><a href="http://www.h.u-tokyo.ac.jp/index.html" target="_blank" class="u-arrow-black">医学部附属病院<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></a></li>
#                                     <li><a href="http://www.h.ims.u-tokyo.ac.jp/" target="_blank" class="u-arrow-black">医科学研究所附属病院<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></a></li>
#                                     <li><a href="https://www.lib.u-tokyo.ac.jp/ja" target="_blank" class="u-arrow-black">図書館<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></a></li>
#                                     <li><a href="/ja/society/research-contribution/museum.html" class="u-arrow-black">博物館</a></li>
#                                             </ul>
#                                         </dd>
#                                     </dl>
#                                 </div>
#                                 <div class="l-col-xs-12 l-col-sm-4">
#                                     <dl class="p-top-link__list">
#                                         <dt>コンプライアンス</dt>
#                                         <dd>
#                                             <ul>
#                                     <li><a href="/ja/about/rules/b08_01.html" class="u-arrow-black">規則・コンプライアンス</a></li>
#                                     <li><a href="http://dcs.adm.u-tokyo.ac.jp/" target="_blank" class="u-arrow-black">キャンパスマナー・相談<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></a></li>
#                                     <li><a href="/ja/students/edu-data/index.html" class="u-arrow-black">教育情報の公表</a></li>
#                                     <li><a href="/ja/about/procurement-contracts/chotatsu-index.html" class="u-arrow-black">調達情報(公告)等</a></li>
#                                     <li><a href="/ja/general/webaccessibility.html" class="u-arrow-black">東京大学ウェブアクセシビリティ方針</a></li>
#                                             </ul>
#                                         </dd>
#                                     </dl>
#                                 </div>
#                                 <div class="l-col-xs-12 l-col-sm-4">
#                                     <dl class="p-top-power">
#                                         <dt>東京大学の電力使用状況</dt>
#                                         <dd id="side_elec">
#                                             <div id="side_elec_data">
#                                             <div id="side_elec_per"><img alt="1" height="43" id="ep-percent3" src="/content/400007620.gif" width="9" /> <img alt="2" height="43" id="ep-percent2" src="/content/400007619.gif" width="27" /> <img alt="3" height="43" id="ep-percent1" src="/content/400007619.gif" width="27" /></div>
#
#                                             <div class="fLeft"><img alt="" src="/content/400007662.gif" width="28" /></div>
#
#                                             <div class="fLeft">
#                                                 <div id="side_elec_time"><img alt="00:00-00:59" height="16" id="ep-time" src="/content/400007624.gif" width="82" /></div>
#
#                                                 <div id="side_elec_kw"><img alt="0" height="19" id="ep-kW6" src="/content/400007621.gif" width="13" /> <img alt="1" height="19" id="ep-kW5" src="/content/400007621.gif" width="13" /> <img alt="2" height="19" id="ep-kW4" src="/content/400007621.gif" width="13" /> <img alt="" height="19" id="side_elec_comma" src="/content/400007622.gif" width="4" /> <img alt="3" height="19" id="ep-kW3" src="/content/400007621.gif" width="13" /> <img alt="4" height="19" id="ep-kW2" src="/content/400007621.gif" width="13" /> <img alt="5" height="19" id="ep-kW1" src="/content/400007621.gif" width="13" /></div>
#                                                 </div>
#                                             </div>
#                                         </dd>
#                                     </dl>
#                                     <p class="p-top-power__link"><a href="http://ep-monitor.adm.u-tokyo.ac.jp/denryoku" class="u-arrow-black" target="_blank">詳細を見る<img src="/content/100074653.png" alt="別ウィンドウで開く" class="window-icon"></a></p>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#
#                 </div>
#                 <!--/ #content -->
#
#             </main>
#             <!-- /MAIN -->
#
#             <footer class="l-footer">
#
#                 <div class="l-footer__top">
#                     <div class="l-footer__inner">
#                         <ul class="l-footer__sns">
#                             <li class="l-footer__sns-item"><a href="https://www.facebook.com/UTokyo.News" target="_blank"><img src="/content/100074629.jpg" alt="Facebook（別ウィンドウで開く）"></a></li>
#                             <li class="l-footer__sns-item"><a href="https://twitter.com/UTokyo_News" target="_blank"><img src="/content/100074651.jpg" alt="Twitter（別ウィンドウで開く）"></a></li>
#                             <li class="l-footer__sns-item"><a href="https://www.youtube.com/user/UTokyoPR/" target="_blank"><img src="/content/100074655.jpg" alt="Youtube（別ウィンドウで開く）"></a></li>
#                             <li class="l-footer__sns-item l-footer__sns-arrow"><a href="/ja/about/sns/list.html" class="u-arrow-yellow">ソーシャルメディア</a></li>
#                         </ul>
#                         <p class="c-pagetop">
#                             <a href="#content" class="scroll"><img src="/content/100074660.jpg" alt="ページTOPに戻る"></a>
#                         </p>
#                     </div>
#                 </div>
#
#                 <div class="l-footer__body">
#                     <div class="l-footer__inner">
#                         <a href="/focus/ja/articles/z0508_00039.html"><img src="/content/400109180.jpg" class="l-footer__body-logo" alt="東京大学"></a>
#                         <p class="l-footer__body-disaster-information-site"><a href="https://blogs.yahoo.co.jp/utokyo_disasterinfo" target="_blank">東京大学災害時情報サイト<img src="/content/100075725.png" alt="別ウィンドウで開く"></a></p>
#                         <ul class="l-footer__body-link">
#                             <li class="l-footer__body-link-item"><a href="/ja/general/sitemap.html">サイトマップ</a></li>
#                             <li class="l-footer__body-link-item"><a href="/ja/general/policy.html">サイトポリシー</a></li>
#                             <li class="l-footer__body-link-item"><a href="/ja/general/privacy_policy.html">プライバシーポリシー</a></li>
#                             <li class="l-footer__body-link-item"><a href="/ja/about/jobs/index.html">採用情報</a></li>
#                             <li class="l-footer__body-link-item"><span lang="en">UTokyo Portal</span>（<a href="https://www.ut-portal.u-tokyo.ac.jp/gakunai/" target="_blank">学内NWから<img src="/content/100075725.png" alt="別ウィンドウで開く"></a> ｜ <a href="/adm/dics/ja/gateway.html" target="_blank">学外NWから<img src="/content/100075725.png" alt="別ウィンドウで開く"></a>）</li>
#                             <li class="l-footer__body-link-item"><a href="/ja/general/qa.html">よくある質問</a></li>
#                         </ul>
#                         <p class="l-footer__body-text">
#                             本サイトの管理・運営は広報室が行なっています。<br>
#                             各ページの内容に関連するお問い合わせは、<br class="u-sp-block">当該ページに記載の問い合わせ先までお願いします。
#                         </p>
#                         <p class="l-footer__body-access"><a href="#map" data-lity="data-lity" title="アクセス・キャンパスマップが同一画面内で開きます">アクセス・キャンパスマップ</a></p>
#
#                         <address class="l-footer-copyright"><span lang="en">&copy; The University of Tokyo</span></address>
#                     </div>
#                 </div>
#             </footer>
#
#
#         </div>
#         <!-- /.l-wrapper -->
#
#         <div id="map" class="p-remodal remodal" data-remodal-id="map">
#             <div class="p-remodal-map-inner">
#                 <img src="/content/100097951.jpg" alt="アクセス・キャンパスマップ">
#                 <p id="kashiwaMap" class="p-remodal-map-link p-remodal-map-link-1"><a href="#map1" data-lity="data-lity"><span>柏キャンパス</span></a></p>
#                 <p id="hongoMap" class="p-remodal-map-link p-remodal-map-link-2"><a href="#map2" data-lity="data-lity"><span>本郷キャンパス</span></a></p>
#                 <p id="komabaMap" class="p-remodal-map-link p-remodal-map-link-3"><a href="#map3" data-lity="data-lity"><span>駒場キャンパス</span></a></p>
#                 <p id="campusGuideLink" class="p-remodal-map-link p-remodal-map-link-access"><a href="/ja/about/campus-guide/index.html"><span>アクセス・キャンパスマップ</span></a></p>
#             </div>
#             <div id="closeMap"><a data-remodal-action="close" class="remodal-close" href="#"><span>閉じる</span></a></div>
#         </div>
#
#         <div id="map1" class="p-remodal remodal" data-remodal-id="map1">
#             <div class="p-remodal-map-inner">
#                 <img src="/content/100097954.jpg" alt="柏キャンパス">
#                 <p id="btnBack1" class="p-remodal-map-link p-remodal-map-link-back"><a href="#map" data-lity="data-lity"><span>戻る</span></a></p>
#                 <p id="campusGuideLinkKashiwa" class="p-remodal-map-link p-remodal-map-link-access"><a href="/ja/about/campus-guide/index.html#kashiwa"><span>アクセス・キャンパスマップ</span></a></p>
#             </div>
#             <div id="closeMapKashiwa"><a data-remodal-action="close" class="remodal-close" href="#"><span>閉じる</span></a></div>
#         </div>
#
#         <div id="map2" class="p-remodal remodal" data-remodal-id="map2">
#             <div class="p-remodal-map-inner">
#                 <img src="/content/100097952.jpg" alt="本郷キャンパス">
#                 <p id="btnBack2" class="p-remodal-map-link p-remodal-map-link-back"><a href="#map" data-lity="data-lity"><span>戻る</span></a></p>
#                 <p id="campusGuideLinkHongo" class="p-remodal-map-link p-remodal-map-link-access"><a href="/ja/about/campus-guide/index.html#hongo"><span>アクセス・キャンパスマップ</span></a></p>
#             </div>
#             <div id="closeMapHongo"><a data-remodal-action="close" class="remodal-close" href="#"><span>閉じる</span></a></div>
#         </div>
#
#         <div id="map3" class="p-remodal remodal" data-remodal-id="map3">
#             <div class="p-remodal-map-inner">
#                 <img src="/content/100097953.jpg" alt="駒場キャンパス">
#                 <p id="btnBack3" class="p-remodal-map-link p-remodal-map-link-back"><a href="#map" data-lity="data-lity"><span>戻る</span></a></p>
#                 <p id="campusGuideLinkKomaba" class="p-remodal-map-link p-remodal-map-link-access"><a href="/ja/about/campus-guide/index.html#komaba"><span>アクセス・キャンパスマップ</span></a></p>
#             </div>
#             <div id="closeMapKomaba"><a data-remodal-action="close" class="remodal-close" href="#"><span>閉じる</span></a></div>
#         </div>
#
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
#         <script src="/content/remodal.min.js"></script>
#         <script src="/content/slick.min.js"></script>
#         <script src="/content/perfect-scrollbar.min.js"></script>
#         <script src="/content/main.js"></script>
#
#         <script src="/content/power.js"></script>
#
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1926416-1', 'auto');
#   ga('send', 'pageview');
#
#   var trackOutboundLink = function(url) {
#   ga('send', 'event', 'outbound', 'click', url);
#   }
# </script>
# <!-- End Google Analytics -->
#     </body>
# </html>

# %% [markdown]
# ## 2. HTMLの解析
#
# WebページはHTML (HyperText Markup Language）という記述形式で書かれています。
# HTML形式では、
# ```
# <a href="あるサイトのURL">あるサイトの名前</a>
# ```
# とすることで、「あるサイトの名前」という文に「あるサイトのURL」のリンクを張ったり、
#
# ```
# <font size="6" color="#ff6600">あいうえお</font>
# ```
# とすることで、「あいうえお」のフォントサイズを「6」、フォントの色を「#ff6600」に指定することを指しています。
# このコードをブラウザで見ると、ブラウザがそのコードに従って、リンクを張ったり文字の大きさや色を変えたりしてくれるわけです。
#
# ここで、HTMLでは、基本的に`<何かのタグ>`と`</先のタグと同じタグ>`で挟まれるのに注意してください。
# 例えば上の例では`<a>`と`</a>`で挟まれていたり、`<font>`と`</font>`で挟まれていますよね。
# これらの対のタグは、それらで挟まれた文字列に対してパラメータを指定するものです。
# 以降では簡単のため、「始まりのタグ」や「終わりのタグ」と呼ぶことにしましょう。
#
# なお、これらは入れ子にすることができます。
# 例えば
#
# ```
# <a href="http://aaa.www">こんなサイトは<font size="18">ありません！</font></a>
# ```
# のようにすれば、「こんなさいとはありません！」にリンクが張られ、「ありません！」のフォントのサイズが「18」に設定されます。
#
# 実はこのjupyter notebookもHTMLで書かれています。
# ですから、ここにHTMLのタグを書き込むと、ブラウザにその指示が伝わって以下のようになります。
#
# <a href="http://aaa.www">こんなサイトは<font size="18">ありません！</font></a>
#
# ## 2.1 HTMLパーザ
# さて、ブラウザで読み込んで使用する場合はこれでいいのですが、我々がこのデータを使う際には、フォントのサイズやハイパーリンク先のアドレスといったタグを含むコードは使いづらいですよね。
# そこで、このようなHTMLソースを使いやすいデータ形式に整理しましょう。
# これをパースと呼び、パースしてくれるプログラムをパーザと呼びます。
# ここではHTMLのコードをパースするので、「HTMLパーザ」を使います。
#
# ここではシンプルなHTMLパーザとして、Python標準モジュールである`html.parser`を使用します。
# パーザにはほかにも`html5lib`や`lxml`などがあります。
# また、パースした結果を使いやすくするモジュールとして、デフォルトでインストールされている
# `Beautiful soup`というモジュールを使用します。

# %%
from bs4 import BeautifulSoup

# res.textには、上のセルでダウンロードしたHTMLソースが代入されています
soup = BeautifulSoup(res.text, "lxml")

# %% [markdown]
# ## 2.2 パージング結果の利用
#
# これで、`soup`にはHTMLソースをパースした結果が代入されました。
# それではこの中身を見ていきたいと思います。
#
# HTMLでは、そのページ全体のタイトルを、`<title>題名</title>`というように`title`という名前のタグで指定します（これは、ブラウザの上のタブのところに表示されるテキストです）。
# `soup.title`とすると、`title`のタグがつけられた文のうち、一番最初にヒットしたものを出力します（`title`は通常、HTMLソースに一度しか現れません）。

# %%
print(soup.title)
# Out:
# <title>東京大学</title>

# %% [markdown]
# タグの名前`name`や内部のテキスト`text`は以下のようにして取り出せます。

# %%
print(soup.title.name)
print(soup.title.text)
# Out:
# title
# 東京大学

# %% [markdown]
# ## 2.3 何度も現れるタグの処理
#
# `title`はソースに1度しか現れないので上のコードでいいですが、`<a href="http://aaa.com>リンクはこちら</a>`のようなハイパーリンク情報などは、同じページに何度も現れますよね。
# このような情報を取り出すには`find_all`という関数を利用します。
#
# ハイパーリンクの書式は、
# `<a href="[リンク先のURL]">リンクを張る文字</a>`
# です。
# この`[リンク先のURL]`を取り出してみましょう。
# まずはハイパーリンクを示す`a`のタグが貼られている部分を抽出します。

# %%
soup.find_all('a')
# Out:
# [<a href="/ja/index.html"><img alt="東京大学" class="u-img-responsive" src="/content/400109180.jpg"/></a>,
#  <a href="#content">本文へ</a>,
#  <a href="/ja/about/campus-guide/index.html">アクセス・キャンパスマップ</a>,
#  <a href="/ja/general/contact.html">お問い合わせ</a>,
#  <a href="http://utf.u-tokyo.ac.jp/index.html" target="_blank">寄附をお考えの方<img alt="別ウィンドウで開く" src="/content/100075725.png"/></a>,
#  <a class="is-open" href="#"><span lang="en">Language</span></a>,
#  <a href="/en/index.html"><span lang="en">English</span></a>,
#  <a href="/zh/index.html"><span lang="zh">中文</span></a>,
#  <a href="/ko/index.html"><span lang="ko">한국어</span></a>,
#  <a href="/ja/index.html"><span lang="en">HOME</span></a>,
#  <a class="l-gnav__focus" href="/focus/ja/index.html"><img alt="UTokyo FOCUS" src="/content/100074616.jpg"/></a>,
#  <a href="/ja/about/index.html">大学案内</a>,
#  <a href="/ja/about/index.html#category1">大学概要</a>,
#  <a href="/ja/about/index.html#category2">キャンパス案内</a>,
#  <a href="/ja/about/president/b01.html">総長室から</a>,
#  <a href="/ja/about/index.html#category4">称号授与</a>,
#  <a href="/ja/about/index.html#category5">東京大学の歴史</a>,
#  <a href="/ja/about/index.html#category6">広報・刊行物</a>,
#  <a href="/ja/about/index.html#category7">情報公開</a>,
#  <a href="/ja/about/index.html#category8">公表事項</a>,
#  <a href="/ja/about/index.html#category9">東京大学の取り組み</a>,
#  <a href="/ja/about/index.html#category10">規則・コンプライアンス</a>,
#  <a href="/ja/about/index.html#category11">点検・評価</a>,
#  <a href="/ja/about/index.html#category12">キャンパス計画</a>,
#  <a href="/ja/about/index.html#category13">調達・契約</a>,
#  <a href="/ja/about/jobs/index.html">採用情報</a>,
#  <a href="/ja/schools-orgs/index.html">学部・大学院等</a>,
#  <a href="/ja/schools-orgs/faculties/faculty.html">学部</a>,
#  <a href="/ja/schools-orgs/faculties/faculty.html">研究科</a>,
#  <a href="/ja/schools-orgs/centers/institutes.html">附置研究所</a>,
#  <a href="/ja/schools-orgs/centers/centers.html">全学センター</a>,
#  <a href="/ja/schools-orgs/centers/utias.html">国際高等研究所</a>,
#  <a href="/ja/schools-orgs/centers/interdisciplinary.html">学際融合研究施設</a>,
#  <a href="/ja/schools-orgs/centers/joint-use.html">全国共同利用施設</a>,
#  <a href="/ja/schools-orgs/centers/committee.html">機構等(総長室総括委員会設置)</a>,
#  <a href="/ja/schools-orgs/centers/integrate.html">連携研究機構</a>,
#  <a href="/ja/admissions/index.html">入学案内</a>,
#  <a href="/ja/admissions/index.html#category1">学部入学</a>,
#  <a href="/ja/admissions/graduate/e02_02.html">大学院入学・社会人入試</a>,
#  <a href="/ja/admissions/index.html#category3">入学料・授業料</a>,
#  <a href="http://www.u-tokyo.ac.jp/adm/inbound/ja/">海外から東大への留学</a>,
#  <a href="http://www.u-tokyo.ac.jp/adm/inbound/ja/">留学生支援</a>,
#  <a href="/ja/admissions/index.html#category6">統計資料</a>,
#  <a href="/ja/admissions/adm-data/e01_011.html">帰国子女・留学生について</a>,
#  <a href="/ja/admissions/adm-data/e01_02.html">入学者選抜方法等の概要</a>,
#  <a href="/ja/students/index.html">教育・学生生活</a>,
#  <a href="/ja/students/index.html#category1">授業・履修</a>,
#  <a href="/ja/students/index.html#category2">特徴的な教育活動</a>,
#  <a href="/ja/students/index.html#category3">学籍・手続窓口</a>,
#  <a href="/ja/students/index.html#category4">情報サービス・保険</a>,
#  <a href="/ja/students/index.html#category5">授業料・奨学制度・宿舎等</a>,
#  <a href="/ja/students/index.html#category6">課外活動</a>,
#  <a href="/ja/students/index.html#category7">施設利用</a>,
#  <a href="/ja/students/index.html#category8">保健・進路・相談</a>,
#  <a href="/ja/students/index.html#category9">行事・シンボル</a>,
#  <a href="/ja/students/index.html#category10">構内交通・警備・環境</a>,
#  <a href="/ja/students/index.html#category11">東大から海外への留学</a>,
#  <a href="/ja/students/index.html#category12">参考情報</a>,
#  <a href="/ja/students/index.html#category13">規則等</a>,
#  <a href="/ja/students/index.html#category14">教育統計資料</a>,
#  <a href="/ja/research/index.html">研究活動</a>,
#  <a href="/ja/research/index.html#category1">研究組織・プロジェクト</a>,
#  <a href="/ja/research/index.html#category2">制度・統計資料</a>,
#  <a href="/ja/research/index.html#category3">研究倫理・生命倫理</a>,
#  <a href="/ja/research/index.html#category4">安全保障輸出管理</a>,
#  <a href="/ja/research/index.html#category5">研究成果・書籍</a>,
#  <a href="/ja/society/index.html">社会連携</a>,
#  <a href="/ja/society/index.html#category1">社会とともに歩む東京大学</a>,
#  <a href="/ja/society/index.html#category2">研究成果の還元</a>,
#  <a href="/ja/society/index.html#category3">一般見学・公開講座案内</a>,
#  <a href="/ja/society/index.html#category4">社会人向け教育</a>,
#  <a href="/ja/society/index.html#category5">地域等との連携</a>,
#  <a href="/ja/society/index.html#category6">東京大学への支援</a>,
#  <a href="/ja/society/index.html#category7">東京大学からの支援</a>,
#  <a href="/ja/society/index.html#category8">関連施設</a>,
#  <a href="/ja/industry-collab/index.html">産学連携</a>,
#  <a href="/ja/industry-collab/index.html#category1">東京大学の産学連携</a>,
#  <a href="/ja/industry-collab/index.html#category2">産学協創推進本部組織構成</a>,
#  <a href="/ja/industry-collab/index.html#category3">関連組織等(外部サイト)</a>,
#  <a href="/ja/industry-collab/index.html#category4">制度・様式</a>,
#  <a href="/ja/intl-activities/index.html">国際交流</a>,
#  <a href="/ja/intl-activities/index.html#category1">グローバル化に向けた取組み</a>,
#  <a href="/ja/intl-activities/index.html#category2">海外大学との交流</a>,
#  <a href="/ja/intl-activities/index.html#category3">東大生の海外留学等</a>,
#  <a href="/ja/intl-activities/index.html#category4">留学生・外国人研究者サポート</a>,
#  <a href="/ja/intl-activities/index.html#category5">組織</a>,
#  <a href="/ja/intl-activities/index.html#category6">海外拠点</a>,
#  <a href="/ja/intl-activities/index.html#category7">統計資料</a>,
#  <a href="/ja/intl-activities/index.html#category8">学内限定コンテンツ</a>,
#  <a href="/ja/alumni/index.html">卒業生</a>,
#  <a href="/ja/alumni/index.html#category1">学ぶ</a>,
#  <a href="/ja/alumni/index.html#category2">学生を支援する</a>,
#  <a href="/ja/alumni/index.html#category3">集う</a>,
#  <a href="/ja/alumni/index.html#category4">貢献する</a>,
#  <a href="/ja/alumni/index.html#category5">TFT(東京大学オンラインコミュニティ)</a>,
#  <a href="/ja/alumni/index.html#category6">広報</a>,
#  <a href="/ja/alumni/index.html#category7">東京大学校友会</a>,
#  <a href="/ja/alumni/index.html#category8">サービス＆ベネフィット</a>,
#  <a href="/focus/ja/people/">教員検索</a>,
#  <a href="/ja/index.html"><span lang="en">HOME</span></a>,
#  <a href="/ja/about/index.html">大学案内</a>,
#  <a href="/ja/schools-orgs/index.html">学部・大学院等</a>,
#  <a href="/ja/admissions/index.html">入学案内</a>,
#  <a href="/ja/students/index.html">教育・学生生活</a>,
#  <a href="/ja/research/index.html">研究活動</a>,
#  <a href="/ja/society/index.html">社会連携</a>,
#  <a href="/ja/industry-collab/index.html">産学連携</a>,
#  <a href="/ja/intl-activities/index.html">国際交流</a>,
#  <a href="/ja/alumni/index.html">卒業生</a>,
#  <a href="/focus/ja/index.html" lang="en">UTokyo <span>FOCUS</span></a>,
#  <a href="/ja/about/campus-guide/index.html">アクセス・キャンパスマップ</a>,
#  <a href="http://utf.u-tokyo.ac.jp/index.html" target="_blank">寄付をお考えの方<img alt="別ウィンドウで開く" src="/content/100074653.png"/></a>,
#  <a href="/ja/general/contact.html">お問い合わせ</a>,
#  <a href="/en/index.html"><span lang="en">English</span></a>,
#  <a href="/zh/index.html"><span lang="zh">中文</span></a>,
#  <a href="/ko/index.html"><span lang="ko">한국어</span></a>,
#  <a href="https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA"><img alt="" src="/content/400119944.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">FSIプロジェクトシリーズ<br/>国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。</div>
#  </div>
#  </a>,
#  <a href="/focus/ja/features/voices069.html"><img alt="" src="/content/400119832.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">UTOKYO VOICES<br/>光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。</div>
#  </div>
#  </a>,
#  <a href="/opendays/index.html"><img alt="" src="/content/400119155.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">「高校生のためのオープンキャンパス2019」<br/>2019年8月7日(水)･ 8日(木)に実施します。</div>
#  </div>
#  </a>,
#  <a href="/focus/ja/features/z0508_00132.html"><img alt="" src="/content/400118046.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">UTokyo FOCUS<br/>足立区と東大の｢おいしい｣関係</div>
#  </div>
#  </a>,
#  <a href="https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894" target="_blank"><img alt="別ウィンドウで開く" src="/content/400117191.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">キミの東大<br/>薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授</div>
#  </div>
#  </a>,
#  <a href="/ja/about/public-relations/tansei.html"><img alt="" src="/content/400110613.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">東京大学広報誌<br/>「淡青」38号</div>
#  </div>
#  </a>,
#  <a href="http://www.tc.u-tokyo.ac.jp/ja/" target="_blank"><img alt="別ウィンドウで開く" src="/content/400109797.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">東京カレッジ<br/>世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。</div>
#  </div>
#  </a>,
#  <a href="https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA"><img alt="" src="/content/400119944.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">FSIプロジェクトシリーズ<br/>国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。</div>
#  </div>
#  </a>,
#  <a href="/focus/ja/features/voices069.html"><img alt="" src="/content/400119832.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">UTOKYO VOICES<br/>光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。</div>
#  </div>
#  </a>,
#  <a href="/opendays/index.html"><img alt="" src="/content/400119155.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">「高校生のためのオープンキャンパス2019」<br/>2019年8月7日(水)･ 8日(木)に実施します。</div>
#  </div>
#  </a>,
#  <a href="/focus/ja/features/z0508_00132.html"><img alt="" src="/content/400118046.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">UTokyo FOCUS<br/>足立区と東大の｢おいしい｣関係</div>
#  </div>
#  </a>,
#  <a href="https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894" target="_blank"><img alt="別ウィンドウで開く" src="/content/400117191.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">キミの東大<br/>薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授</div>
#  </div>
#  </a>,
#  <a href="/ja/about/public-relations/tansei.html"><img alt="" src="/content/400110613.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">東京大学広報誌<br/>「淡青」38号</div>
#  </div>
#  </a>,
#  <a href="http://www.tc.u-tokyo.ac.jp/ja/" target="_blank"><img alt="別ウィンドウで開く" src="/content/400109797.jpg"/>
#  <div class="p-slider-msg">
#  <div class="p-slider-msg-inner">東京カレッジ<br/>世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。</div>
#  </div>
#  </a>,
#  <a href="/focus/ja/articles/z1201_00001.html"><span>2019年6月14日</span>【注意喚起】東京大学を装った迷惑メール（なりすまし）にご注意ください（本部情報戦略課）</a>,
#  <a href="/ja/admissions/undergraduate/e01_admission_method_05.html"><span>2019年3月8日</span>2021年度入学者選抜（2020年度実施）に関する予告について（本部入試課）</a>,
#  <a href="/ja/admissions/undergraduate/e01_05.html"><span>2019年3月8日</span>平成31年度前期日程試験における試験問題及び解答等の公表について（本部入試課）</a>,
#  <a href="/focus/ja/articles/z0603_00005.html"><span>2018年9月10日</span>平成30年8月30日からの大雨ならびに平成30年北海道胆振東部地震で被災した世帯の学生の皆さんへ (本部奨学厚生課)</a>,
#  <a href="/focus/ja/articles/z0603_00003.html"><span>2018年7月10日</span>平成30年台風第7号及び前線等に伴う大雨で被災した世帯の学生の皆さんへ (本部奨学厚生課)</a>,
#  <a href="/focus/ja/index.html">UTokyo FOCUSへ</a>,
#  <a href="/focus/ja/features/fsi013.html">
#  <figure class="p-top-focus__image-box">
#  <img alt="" src="/content/400117278.jpg"/>
#  </figure>
#  <p class="p-top-focus__item-text">宇宙用から、地球用へ</p>
#  <p class="p-top-focus__item-date">2019年7月15日</p>
#  <p class="p-top-focus__item-tag" lang="en">科学と技術</p>
#  </a>,
#  <a href="/focus/ja/features/voices069.html">
#  <figure class="p-top-focus__image-box">
#  <img alt="" src="/content/400119211.jpg"/>
#  </figure>
#  <p class="p-top-focus__item-text">光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。...</p>
#  <p class="p-top-focus__item-date">2019年7月11日</p>
#  <p class="p-top-focus__item-tag" lang="en">UTOKYO VOICES</p>
#  </a>,
#  <a href="/focus/ja/articles/z0102_00075.html">
#  <figure class="p-top-focus__image-box">
#  <img alt="" src="/content/100074697.jpg"/>
#  </figure>
#  <p class="p-top-focus__item-text">「2019年度厚生労働省臨床研究総合促進事業　治験・倫理審査委員会委員...</p>
#  <p class="p-top-focus__item-date">2019年7月11日</p>
#  <p class="p-top-focus__item-tag" lang="en">お知らせ</p>
#  </a>,
#  <a href="/focus/ja/events/z0106_00007.html">
#  <span><img alt="" src="/content/100074625.png"/></span>
#  <div class="p-top-events__item-body">
#  <p class="p-top-events__item-date">2019年8月24日</p>
#  <p class="p-top-events__item-title">第104回小石川植物園市民セミナーのご案内</p>
#  </div>
#  </a>,
#  <a href="/focus/ja/events/z0202_00011.html">
#  <span><img alt="" src="/content/100074624.png"/></span>
#  <div class="p-top-events__item-body">
#  <p class="p-top-events__item-date">2019年7月23日—2019年7月26日</p>
#  <p class="p-top-events__item-title">地震研究所×北京大学地球空間科学学院「第1回固体地球科学サマースクール"Dyna...</p>
#  </div>
#  </a>,
#  <a href="/focus/ja/events/z0211_00065.html">
#  <span><img alt="" src="/content/100074625.png"/></span>
#  <div class="p-top-events__item-body">
#  <p class="p-top-events__item-date">2019年7月18日</p>
#  <p class="p-top-events__item-title">RCAST Security Seminar #16 米中貿易戦争と日本</p>
#  </div>
#  </a>,
#  <a href="/focus/ja/events">イベントカレンダー</a>,
#  <a href="/adm/fsi/ja/index.html">
#  <figure><img alt="" src="/content/400094844.png"/></figure>
#  <p class="p-top-highlights__item-title">未来社会協創推進本部</p>
#  </a>,
#  <a href="/ja/about/president/index.html">
#  <figure><img alt="" src="/content/400094843.jpg"/></figure>
#  <p class="p-top-highlights__item-title">総長談論</p>
#  </a>,
#  <a href="/ja/admissions/undergraduate/e01_26.html">
#  <figure><img alt="" src="/content/400088087.jpg"/></figure>
#  <p class="p-top-highlights__item-title">東京大学 推薦入試</p>
#  </a>,
#  <a href="/ja/about/public-relations/IRIR.html">
#  <figure><img alt="" src="/content/400101527.jpg"/></figure>
#  <p class="p-top-highlights__item-title">統合報告書2018</p>
#  </a>,
#  <a href="/ja/admissions/undergraduate/e01_07_14.html">
#  <p class="p-top-updates__list-date">2019年7月12日</p>
#  <p class="p-top-updates__list-title">主要大学説明会2019</p>
#  </a>,
#  <a href="/adm/fsi/ja/symposium.html">
#  <p class="p-top-updates__list-date">2019年7月12日</p>
#  <p class="p-top-updates__list-title">FSIシンポジウム・シリーズ</p>
#  </a>,
#  <a href="/ja/alumni/support-programs/mentar.html">
#  <p class="p-top-updates__list-date">2019年7月4日</p>
#  <p class="p-top-updates__list-title">卒業生によるキャリア支援</p>
#  </a>,
#  <a href="/ja/about/public-relations/kouhou.html">
#  <p class="p-top-updates__list-date">2019年7月3日</p>
#  <p class="p-top-updates__list-title">広報誌 「学内広報」</p>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="/ja/intl-activities/global/sgu.html">
#  <p class="p-top-intiatives__item-title">グローバルキャンパスモデルの構築</p>
#  <figure><img alt="" src="/content/400088097.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="/adm/go-gateway/ja/index.html">
#  <p class="p-top-intiatives__item-title">Go Global Gateway</p>
#  <figure><img alt="" src="/content/400092280.png"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="/ja/society/visit-lectures/mooc.html">
#  <p class="p-top-intiatives__item-title">公開オンライン講座<br/>MOOCs</p>
#  <figure><img alt="" src="/content/400088091.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://ocw.u-tokyo.ac.jp/" target="_blank">
#  <p class="p-top-intiatives__item-title">東京大学の正規授業のネット配信<br/>OCW<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400088090.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://todai.tv/" target="_blank">
#  <p class="p-top-intiatives__item-title">公開講座や各種イベント動画を配信<br/>東大TV<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400088089.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://todainavi.jp/" target="_blank">
#  <p class="p-top-intiatives__item-title">東京大学公式イベント情報<br/>東大ナビ<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400088088.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://coref.u-tokyo.ac.jp/" target="_blank">
#  <p class="p-top-intiatives__item-title">大学発教育支援コンソーシアム<br/>CoREF<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400092281.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://www.emp.u-tokyo.ac.jp/" target="_blank">
#  <p class="p-top-intiatives__item-title">次世代を切り拓く人材を育成<br/>東大EMP<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400092481.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="https://utcc.u-tokyo.ac.jp/" target="_blank">
#  <p class="p-top-intiatives__item-title">コミュニケーションセンター<br/>UTCC<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400092282.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="/biblioplaza/ja/index.html">
#  <p class="p-top-intiatives__item-title">UTokyo Biblio Plaza</p>
#  <figure><img alt="" src="/content/400088093.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://utssi.c.u-tokyo.ac.jp/index.html" target="_blank">
#  <p class="p-top-intiatives__item-title">スポーツ先端科学<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400088094.jpg"/></figure>
#  </a>,
#  <a class="p-top-intiatives__item-image" href="http://kyodo-sankaku.u-tokyo.ac.jp/index.html" target="_blank">
#  <p class="p-top-intiatives__item-title">男女共同参画<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></p>
#  <figure><img alt="" src="/content/400106907.jpg"/></figure>
#  </a>,
#  <a href="/ja/society/aid/info.html">
#  <p class="p-top-intiatives__item-title">東日本大震災<br/>東京大学の対応</p>
#  </a>,
#  <a href="/ja/about/history/140ut.html">
#  <p class="p-top-intiatives__item-title">140周年創設記念事業</p>
#  </a>,
#  <a href="/biblioplaza/ja/D_00001.html"><div class="p-top-book">
#  <figure><img alt="白い表紙にベージュの模様" src="/content/400112267.jpg"/></figure>
#  <div class="p-top-book__body">
#  <p class="p-top-book__body-title">行政学講義</p>
#  <p class="p-top-book__body-sub-title">金井 利之
#  </p>
#  <p class="p-top-book__body-text">本書は、一般読者向けに、日本の行政と官僚制を紹介するものである。タイトルは、「行政学講義」となってい...[続きを見る]</p>
#  </div>
#  </div></a>,
#  <a href="https://youtu.be/z6itIL3Gvy0" target="_blank"><img alt="Movie" src="/content/400115014.png"/></a>,
#  <a class="u-arrow-black" href="http://www.h.u-tokyo.ac.jp/index.html" target="_blank">医学部附属病院<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></a>,
#  <a class="u-arrow-black" href="http://www.h.ims.u-tokyo.ac.jp/" target="_blank">医科学研究所附属病院<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></a>,
#  <a class="u-arrow-black" href="https://www.lib.u-tokyo.ac.jp/ja" target="_blank">図書館<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></a>,
#  <a class="u-arrow-black" href="/ja/society/research-contribution/museum.html">博物館</a>,
#  <a class="u-arrow-black" href="/ja/about/rules/b08_01.html">規則・コンプライアンス</a>,
#  <a class="u-arrow-black" href="http://dcs.adm.u-tokyo.ac.jp/" target="_blank">キャンパスマナー・相談<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></a>,
#  <a class="u-arrow-black" href="/ja/students/edu-data/index.html">教育情報の公表</a>,
#  <a class="u-arrow-black" href="/ja/about/procurement-contracts/chotatsu-index.html">調達情報(公告)等</a>,
#  <a class="u-arrow-black" href="/ja/general/webaccessibility.html">東京大学ウェブアクセシビリティ方針</a>,
#  <a class="u-arrow-black" href="http://ep-monitor.adm.u-tokyo.ac.jp/denryoku" target="_blank">詳細を見る<img alt="別ウィンドウで開く" class="window-icon" src="/content/100074653.png"/></a>,
#  <a href="https://www.facebook.com/UTokyo.News" target="_blank"><img alt="Facebook（別ウィンドウで開く）" src="/content/100074629.jpg"/></a>,
#  <a href="https://twitter.com/UTokyo_News" target="_blank"><img alt="Twitter（別ウィンドウで開く）" src="/content/100074651.jpg"/></a>,
#  <a href="https://www.youtube.com/user/UTokyoPR/" target="_blank"><img alt="Youtube（別ウィンドウで開く）" src="/content/100074655.jpg"/></a>,
#  <a class="u-arrow-yellow" href="/ja/about/sns/list.html">ソーシャルメディア</a>,
#  <a class="scroll" href="#content"><img alt="ページTOPに戻る" src="/content/100074660.jpg"/></a>,
#  <a href="/focus/ja/articles/z0508_00039.html"><img alt="東京大学" class="l-footer__body-logo" src="/content/400109180.jpg"/></a>,
#  <a href="https://blogs.yahoo.co.jp/utokyo_disasterinfo" target="_blank">東京大学災害時情報サイト<img alt="別ウィンドウで開く" src="/content/100075725.png"/></a>,
#  <a href="/ja/general/sitemap.html">サイトマップ</a>,
#  <a href="/ja/general/policy.html">サイトポリシー</a>,
#  <a href="/ja/general/privacy_policy.html">プライバシーポリシー</a>,
#  <a href="/ja/about/jobs/index.html">採用情報</a>,
#  <a href="https://www.ut-portal.u-tokyo.ac.jp/gakunai/" target="_blank">学内NWから<img alt="別ウィンドウで開く" src="/content/100075725.png"/></a>,
#  <a href="/adm/dics/ja/gateway.html" target="_blank">学外NWから<img alt="別ウィンドウで開く" src="/content/100075725.png"/></a>,
#  <a href="/ja/general/qa.html">よくある質問</a>,
#  <a data-lity="data-lity" href="#map" title="アクセス・キャンパスマップが同一画面内で開きます">アクセス・キャンパスマップ</a>,
#  <a data-lity="data-lity" href="#map1"><span>柏キャンパス</span></a>,
#  <a data-lity="data-lity" href="#map2"><span>本郷キャンパス</span></a>,
#  <a data-lity="data-lity" href="#map3"><span>駒場キャンパス</span></a>,
#  <a href="/ja/about/campus-guide/index.html"><span>アクセス・キャンパスマップ</span></a>,
#  <a class="remodal-close" data-remodal-action="close" href="#"><span>閉じる</span></a>,
#  <a data-lity="data-lity" href="#map"><span>戻る</span></a>,
#  <a href="/ja/about/campus-guide/index.html#kashiwa"><span>アクセス・キャンパスマップ</span></a>,
#  <a class="remodal-close" data-remodal-action="close" href="#"><span>閉じる</span></a>,
#  <a data-lity="data-lity" href="#map"><span>戻る</span></a>,
#  <a href="/ja/about/campus-guide/index.html#hongo"><span>アクセス・キャンパスマップ</span></a>,
#  <a class="remodal-close" data-remodal-action="close" href="#"><span>閉じる</span></a>,
#  <a data-lity="data-lity" href="#map"><span>戻る</span></a>,
#  <a href="/ja/about/campus-guide/index.html#komaba"><span>アクセス・キャンパスマップ</span></a>,
#  <a class="remodal-close" data-remodal-action="close" href="#"><span>閉じる</span></a>]

# %% [markdown]
# リンク先のURLは、`a`のタグの中にある`href`に代入されている値ですから、リンク先のURLを出力したいときは、以下のようにすればいいでしょう。

# %%
for address in soup.find_all('a'):
    print('ハイパーリンクが張られている文:', address.text)
    print('URL: ', address['href'])
# Out:
# ハイパーリンクが張られている文:
# URL:  /ja/index.html
# ハイパーリンクが張られている文: 本文へ
# URL:  #content
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html
# ハイパーリンクが張られている文: お問い合わせ
# URL:  /ja/general/contact.html
# ハイパーリンクが張られている文: 寄附をお考えの方
# URL:  http://utf.u-tokyo.ac.jp/index.html
# ハイパーリンクが張られている文: Language
# URL:  #
# ハイパーリンクが張られている文: English
# URL:  /en/index.html
# ハイパーリンクが張られている文: 中文
# URL:  /zh/index.html
# ハイパーリンクが張られている文: 한국어
# URL:  /ko/index.html
# ハイパーリンクが張られている文: HOME
# URL:  /ja/index.html
# ハイパーリンクが張られている文:
# URL:  /focus/ja/index.html
# ハイパーリンクが張られている文: 大学案内
# URL:  /ja/about/index.html
# ハイパーリンクが張られている文: 大学概要
# URL:  /ja/about/index.html#category1
# ハイパーリンクが張られている文: キャンパス案内
# URL:  /ja/about/index.html#category2
# ハイパーリンクが張られている文: 総長室から
# URL:  /ja/about/president/b01.html
# ハイパーリンクが張られている文: 称号授与
# URL:  /ja/about/index.html#category4
# ハイパーリンクが張られている文: 東京大学の歴史
# URL:  /ja/about/index.html#category5
# ハイパーリンクが張られている文: 広報・刊行物
# URL:  /ja/about/index.html#category6
# ハイパーリンクが張られている文: 情報公開
# URL:  /ja/about/index.html#category7
# ハイパーリンクが張られている文: 公表事項
# URL:  /ja/about/index.html#category8
# ハイパーリンクが張られている文: 東京大学の取り組み
# URL:  /ja/about/index.html#category9
# ハイパーリンクが張られている文: 規則・コンプライアンス
# URL:  /ja/about/index.html#category10
# ハイパーリンクが張られている文: 点検・評価
# URL:  /ja/about/index.html#category11
# ハイパーリンクが張られている文: キャンパス計画
# URL:  /ja/about/index.html#category12
# ハイパーリンクが張られている文: 調達・契約
# URL:  /ja/about/index.html#category13
# ハイパーリンクが張られている文: 採用情報
# URL:  /ja/about/jobs/index.html
# ハイパーリンクが張られている文: 学部・大学院等
# URL:  /ja/schools-orgs/index.html
# ハイパーリンクが張られている文: 学部
# URL:  /ja/schools-orgs/faculties/faculty.html
# ハイパーリンクが張られている文: 研究科
# URL:  /ja/schools-orgs/faculties/faculty.html
# ハイパーリンクが張られている文: 附置研究所
# URL:  /ja/schools-orgs/centers/institutes.html
# ハイパーリンクが張られている文: 全学センター
# URL:  /ja/schools-orgs/centers/centers.html
# ハイパーリンクが張られている文: 国際高等研究所
# URL:  /ja/schools-orgs/centers/utias.html
# ハイパーリンクが張られている文: 学際融合研究施設
# URL:  /ja/schools-orgs/centers/interdisciplinary.html
# ハイパーリンクが張られている文: 全国共同利用施設
# URL:  /ja/schools-orgs/centers/joint-use.html
# ハイパーリンクが張られている文: 機構等(総長室総括委員会設置)
# URL:  /ja/schools-orgs/centers/committee.html
# ハイパーリンクが張られている文: 連携研究機構
# URL:  /ja/schools-orgs/centers/integrate.html
# ハイパーリンクが張られている文: 入学案内
# URL:  /ja/admissions/index.html
# ハイパーリンクが張られている文: 学部入学
# URL:  /ja/admissions/index.html#category1
# ハイパーリンクが張られている文: 大学院入学・社会人入試
# URL:  /ja/admissions/graduate/e02_02.html
# ハイパーリンクが張られている文: 入学料・授業料
# URL:  /ja/admissions/index.html#category3
# ハイパーリンクが張られている文: 海外から東大への留学
# URL:  http://www.u-tokyo.ac.jp/adm/inbound/ja/
# ハイパーリンクが張られている文: 留学生支援
# URL:  http://www.u-tokyo.ac.jp/adm/inbound/ja/
# ハイパーリンクが張られている文: 統計資料
# URL:  /ja/admissions/index.html#category6
# ハイパーリンクが張られている文: 帰国子女・留学生について
# URL:  /ja/admissions/adm-data/e01_011.html
# ハイパーリンクが張られている文: 入学者選抜方法等の概要
# URL:  /ja/admissions/adm-data/e01_02.html
# ハイパーリンクが張られている文: 教育・学生生活
# URL:  /ja/students/index.html
# ハイパーリンクが張られている文: 授業・履修
# URL:  /ja/students/index.html#category1
# ハイパーリンクが張られている文: 特徴的な教育活動
# URL:  /ja/students/index.html#category2
# ハイパーリンクが張られている文: 学籍・手続窓口
# URL:  /ja/students/index.html#category3
# ハイパーリンクが張られている文: 情報サービス・保険
# URL:  /ja/students/index.html#category4
# ハイパーリンクが張られている文: 授業料・奨学制度・宿舎等
# URL:  /ja/students/index.html#category5
# ハイパーリンクが張られている文: 課外活動
# URL:  /ja/students/index.html#category6
# ハイパーリンクが張られている文: 施設利用
# URL:  /ja/students/index.html#category7
# ハイパーリンクが張られている文: 保健・進路・相談
# URL:  /ja/students/index.html#category8
# ハイパーリンクが張られている文: 行事・シンボル
# URL:  /ja/students/index.html#category9
# ハイパーリンクが張られている文: 構内交通・警備・環境
# URL:  /ja/students/index.html#category10
# ハイパーリンクが張られている文: 東大から海外への留学
# URL:  /ja/students/index.html#category11
# ハイパーリンクが張られている文: 参考情報
# URL:  /ja/students/index.html#category12
# ハイパーリンクが張られている文: 規則等
# URL:  /ja/students/index.html#category13
# ハイパーリンクが張られている文: 教育統計資料
# URL:  /ja/students/index.html#category14
# ハイパーリンクが張られている文: 研究活動
# URL:  /ja/research/index.html
# ハイパーリンクが張られている文: 研究組織・プロジェクト
# URL:  /ja/research/index.html#category1
# ハイパーリンクが張られている文: 制度・統計資料
# URL:  /ja/research/index.html#category2
# ハイパーリンクが張られている文: 研究倫理・生命倫理
# URL:  /ja/research/index.html#category3
# ハイパーリンクが張られている文: 安全保障輸出管理
# URL:  /ja/research/index.html#category4
# ハイパーリンクが張られている文: 研究成果・書籍
# URL:  /ja/research/index.html#category5
# ハイパーリンクが張られている文: 社会連携
# URL:  /ja/society/index.html
# ハイパーリンクが張られている文: 社会とともに歩む東京大学
# URL:  /ja/society/index.html#category1
# ハイパーリンクが張られている文: 研究成果の還元
# URL:  /ja/society/index.html#category2
# ハイパーリンクが張られている文: 一般見学・公開講座案内
# URL:  /ja/society/index.html#category3
# ハイパーリンクが張られている文: 社会人向け教育
# URL:  /ja/society/index.html#category4
# ハイパーリンクが張られている文: 地域等との連携
# URL:  /ja/society/index.html#category5
# ハイパーリンクが張られている文: 東京大学への支援
# URL:  /ja/society/index.html#category6
# ハイパーリンクが張られている文: 東京大学からの支援
# URL:  /ja/society/index.html#category7
# ハイパーリンクが張られている文: 関連施設
# URL:  /ja/society/index.html#category8
# ハイパーリンクが張られている文: 産学連携
# URL:  /ja/industry-collab/index.html
# ハイパーリンクが張られている文: 東京大学の産学連携
# URL:  /ja/industry-collab/index.html#category1
# ハイパーリンクが張られている文: 産学協創推進本部組織構成
# URL:  /ja/industry-collab/index.html#category2
# ハイパーリンクが張られている文: 関連組織等(外部サイト)
# URL:  /ja/industry-collab/index.html#category3
# ハイパーリンクが張られている文: 制度・様式
# URL:  /ja/industry-collab/index.html#category4
# ハイパーリンクが張られている文: 国際交流
# URL:  /ja/intl-activities/index.html
# ハイパーリンクが張られている文: グローバル化に向けた取組み
# URL:  /ja/intl-activities/index.html#category1
# ハイパーリンクが張られている文: 海外大学との交流
# URL:  /ja/intl-activities/index.html#category2
# ハイパーリンクが張られている文: 東大生の海外留学等
# URL:  /ja/intl-activities/index.html#category3
# ハイパーリンクが張られている文: 留学生・外国人研究者サポート
# URL:  /ja/intl-activities/index.html#category4
# ハイパーリンクが張られている文: 組織
# URL:  /ja/intl-activities/index.html#category5
# ハイパーリンクが張られている文: 海外拠点
# URL:  /ja/intl-activities/index.html#category6
# ハイパーリンクが張られている文: 統計資料
# URL:  /ja/intl-activities/index.html#category7
# ハイパーリンクが張られている文: 学内限定コンテンツ
# URL:  /ja/intl-activities/index.html#category8
# ハイパーリンクが張られている文: 卒業生
# URL:  /ja/alumni/index.html
# ハイパーリンクが張られている文: 学ぶ
# URL:  /ja/alumni/index.html#category1
# ハイパーリンクが張られている文: 学生を支援する
# URL:  /ja/alumni/index.html#category2
# ハイパーリンクが張られている文: 集う
# URL:  /ja/alumni/index.html#category3
# ハイパーリンクが張られている文: 貢献する
# URL:  /ja/alumni/index.html#category4
# ハイパーリンクが張られている文: TFT(東京大学オンラインコミュニティ)
# URL:  /ja/alumni/index.html#category5
# ハイパーリンクが張られている文: 広報
# URL:  /ja/alumni/index.html#category6
# ハイパーリンクが張られている文: 東京大学校友会
# URL:  /ja/alumni/index.html#category7
# ハイパーリンクが張られている文: サービス＆ベネフィット
# URL:  /ja/alumni/index.html#category8
# ハイパーリンクが張られている文: 教員検索
# URL:  /focus/ja/people/
# ハイパーリンクが張られている文: HOME
# URL:  /ja/index.html
# ハイパーリンクが張られている文: 大学案内
# URL:  /ja/about/index.html
# ハイパーリンクが張られている文: 学部・大学院等
# URL:  /ja/schools-orgs/index.html
# ハイパーリンクが張られている文: 入学案内
# URL:  /ja/admissions/index.html
# ハイパーリンクが張られている文: 教育・学生生活
# URL:  /ja/students/index.html
# ハイパーリンクが張られている文: 研究活動
# URL:  /ja/research/index.html
# ハイパーリンクが張られている文: 社会連携
# URL:  /ja/society/index.html
# ハイパーリンクが張られている文: 産学連携
# URL:  /ja/industry-collab/index.html
# ハイパーリンクが張られている文: 国際交流
# URL:  /ja/intl-activities/index.html
# ハイパーリンクが張られている文: 卒業生
# URL:  /ja/alumni/index.html
# ハイパーリンクが張られている文: UTokyo FOCUS
# URL:  /focus/ja/index.html
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html
# ハイパーリンクが張られている文: 寄付をお考えの方
# URL:  http://utf.u-tokyo.ac.jp/index.html
# ハイパーリンクが張られている文: お問い合わせ
# URL:  /ja/general/contact.html
# ハイパーリンクが張られている文: English
# URL:  /en/index.html
# ハイパーリンクが張られている文: 中文
# URL:  /zh/index.html
# ハイパーリンクが張られている文: 한국어
# URL:  /ko/index.html
# ハイパーリンクが張られている文:
#
# FSIプロジェクトシリーズ国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。
#
#
# URL:  https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA
# ハイパーリンクが張られている文:
#
# UTOKYO VOICES光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。
#
#
# URL:  /focus/ja/features/voices069.html
# ハイパーリンクが張られている文:
#
# 「高校生のためのオープンキャンパス2019」2019年8月7日(水)･ 8日(木)に実施します。
#
#
# URL:  /opendays/index.html
# ハイパーリンクが張られている文:
#
# UTokyo FOCUS足立区と東大の｢おいしい｣関係
#
#
# URL:  /focus/ja/features/z0508_00132.html
# ハイパーリンクが張られている文:
#
# キミの東大薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授
#
#
# URL:  https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894
# ハイパーリンクが張られている文:
#
# 東京大学広報誌「淡青」38号
#
#
# URL:  /ja/about/public-relations/tansei.html
# ハイパーリンクが張られている文:
#
# 東京カレッジ世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。
#
#
# URL:  http://www.tc.u-tokyo.ac.jp/ja/
# ハイパーリンクが張られている文:
#
# FSIプロジェクトシリーズ国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。
#
#
# URL:  https://www.u-tokyo.ac.jp/focus/ja/tags/?tag=FSI%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA
# ハイパーリンクが張られている文:
#
# UTOKYO VOICES光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。
#
#
# URL:  /focus/ja/features/voices069.html
# ハイパーリンクが張られている文:
#
# 「高校生のためのオープンキャンパス2019」2019年8月7日(水)･ 8日(木)に実施します。
#
#
# URL:  /opendays/index.html
# ハイパーリンクが張られている文:
#
# UTokyo FOCUS足立区と東大の｢おいしい｣関係
#
#
# URL:  /focus/ja/features/z0508_00132.html
# ハイパーリンクが張られている文:
#
# キミの東大薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授
#
#
# URL:  https://kimino.ct.u-tokyo.ac.jp/lab-visit/1894
# ハイパーリンクが張られている文:
#
# 東京大学広報誌「淡青」38号
#
#
# URL:  /ja/about/public-relations/tansei.html
# ハイパーリンクが張られている文:
#
# 東京カレッジ世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。
#
#
# URL:  http://www.tc.u-tokyo.ac.jp/ja/
# ハイパーリンクが張られている文: 2019年6月14日【注意喚起】東京大学を装った迷惑メール（なりすまし）にご注意ください（本部情報戦略課）
# URL:  /focus/ja/articles/z1201_00001.html
# ハイパーリンクが張られている文: 2019年3月8日2021年度入学者選抜（2020年度実施）に関する予告について（本部入試課）
# URL:  /ja/admissions/undergraduate/e01_admission_method_05.html
# ハイパーリンクが張られている文: 2019年3月8日平成31年度前期日程試験における試験問題及び解答等の公表について（本部入試課）
# URL:  /ja/admissions/undergraduate/e01_05.html
# ハイパーリンクが張られている文: 2018年9月10日平成30年8月30日からの大雨ならびに平成30年北海道胆振東部地震で被災した世帯の学生の皆さんへ (本部奨学厚生課)
# URL:  /focus/ja/articles/z0603_00005.html
# ハイパーリンクが張られている文: 2018年7月10日平成30年台風第7号及び前線等に伴う大雨で被災した世帯の学生の皆さんへ (本部奨学厚生課)
# URL:  /focus/ja/articles/z0603_00003.html
# ハイパーリンクが張られている文: UTokyo FOCUSへ
# URL:  /focus/ja/index.html
# ハイパーリンクが張られている文:
#
#
#
# 宇宙用から、地球用へ
# 2019年7月15日
# 科学と技術
#
# URL:  /focus/ja/features/fsi013.html
# ハイパーリンクが張られている文:
#
#
#
# 光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。...
# 2019年7月11日
# UTOKYO VOICES
#
# URL:  /focus/ja/features/voices069.html
# ハイパーリンクが張られている文:
#
#
#
# 「2019年度厚生労働省臨床研究総合促進事業　治験・倫理審査委員会委員...
# 2019年7月11日
# お知らせ
#
# URL:  /focus/ja/articles/z0102_00075.html
# ハイパーリンクが張られている文:
#
#
# 2019年8月24日
# 第104回小石川植物園市民セミナーのご案内
#
#
# URL:  /focus/ja/events/z0106_00007.html
# ハイパーリンクが張られている文:
#
#
# 2019年7月23日—2019年7月26日
# 地震研究所×北京大学地球空間科学学院「第1回固体地球科学サマースクール"Dyna...
#
#
# URL:  /focus/ja/events/z0202_00011.html
# ハイパーリンクが張られている文:
#
#
# 2019年7月18日
# RCAST Security Seminar #16 米中貿易戦争と日本
#
#
# URL:  /focus/ja/events/z0211_00065.html
# ハイパーリンクが張られている文: イベントカレンダー
# URL:  /focus/ja/events
# ハイパーリンクが張られている文:
#
# 未来社会協創推進本部
#
# URL:  /adm/fsi/ja/index.html
# ハイパーリンクが張られている文:
#
# 総長談論
#
# URL:  /ja/about/president/index.html
# ハイパーリンクが張られている文:
#
# 東京大学 推薦入試
#
# URL:  /ja/admissions/undergraduate/e01_26.html
# ハイパーリンクが張られている文:
#
# 統合報告書2018
#
# URL:  /ja/about/public-relations/IRIR.html
# ハイパーリンクが張られている文:
# 2019年7月12日
# 主要大学説明会2019
#
# URL:  /ja/admissions/undergraduate/e01_07_14.html
# ハイパーリンクが張られている文:
# 2019年7月12日
# FSIシンポジウム・シリーズ
#
# URL:  /adm/fsi/ja/symposium.html
# ハイパーリンクが張られている文:
# 2019年7月4日
# 卒業生によるキャリア支援
#
# URL:  /ja/alumni/support-programs/mentar.html
# ハイパーリンクが張られている文:
# 2019年7月3日
# 広報誌 「学内広報」
#
# URL:  /ja/about/public-relations/kouhou.html
# ハイパーリンクが張られている文:
# グローバルキャンパスモデルの構築
#
#
# URL:  /ja/intl-activities/global/sgu.html
# ハイパーリンクが張られている文:
# Go Global Gateway
#
#
# URL:  /adm/go-gateway/ja/index.html
# ハイパーリンクが張られている文:
# 公開オンライン講座MOOCs
#
#
# URL:  /ja/society/visit-lectures/mooc.html
# ハイパーリンクが張られている文:
# 東京大学の正規授業のネット配信OCW
#
#
# URL:  http://ocw.u-tokyo.ac.jp/
# ハイパーリンクが張られている文:
# 公開講座や各種イベント動画を配信東大TV
#
#
# URL:  http://todai.tv/
# ハイパーリンクが張られている文:
# 東京大学公式イベント情報東大ナビ
#
#
# URL:  http://todainavi.jp/
# ハイパーリンクが張られている文:
# 大学発教育支援コンソーシアムCoREF
#
#
# URL:  http://coref.u-tokyo.ac.jp/
# ハイパーリンクが張られている文:
# 次世代を切り拓く人材を育成東大EMP
#
#
# URL:  http://www.emp.u-tokyo.ac.jp/
# ハイパーリンクが張られている文:
# コミュニケーションセンターUTCC
#
#
# URL:  https://utcc.u-tokyo.ac.jp/
# ハイパーリンクが張られている文:
# UTokyo Biblio Plaza
#
#
# URL:  /biblioplaza/ja/index.html
# ハイパーリンクが張られている文:
# スポーツ先端科学
#
#
# URL:  http://utssi.c.u-tokyo.ac.jp/index.html
# ハイパーリンクが張られている文:
# 男女共同参画
#
#
# URL:  http://kyodo-sankaku.u-tokyo.ac.jp/index.html
# ハイパーリンクが張られている文:
# 東日本大震災東京大学の対応
#
# URL:  /ja/society/aid/info.html
# ハイパーリンクが張られている文:
# 140周年創設記念事業
#
# URL:  /ja/about/history/140ut.html
# ハイパーリンクが張られている文:
#
#
# 行政学講義
# 金井 利之
#
# 本書は、一般読者向けに、日本の行政と官僚制を紹介するものである。タイトルは、「行政学講義」となってい...[続きを見る]
#
#
# URL:  /biblioplaza/ja/D_00001.html
# ハイパーリンクが張られている文:
# URL:  https://youtu.be/z6itIL3Gvy0
# ハイパーリンクが張られている文: 医学部附属病院
# URL:  http://www.h.u-tokyo.ac.jp/index.html
# ハイパーリンクが張られている文: 医科学研究所附属病院
# URL:  http://www.h.ims.u-tokyo.ac.jp/
# ハイパーリンクが張られている文: 図書館
# URL:  https://www.lib.u-tokyo.ac.jp/ja
# ハイパーリンクが張られている文: 博物館
# URL:  /ja/society/research-contribution/museum.html
# ハイパーリンクが張られている文: 規則・コンプライアンス
# URL:  /ja/about/rules/b08_01.html
# ハイパーリンクが張られている文: キャンパスマナー・相談
# URL:  http://dcs.adm.u-tokyo.ac.jp/
# ハイパーリンクが張られている文: 教育情報の公表
# URL:  /ja/students/edu-data/index.html
# ハイパーリンクが張られている文: 調達情報(公告)等
# URL:  /ja/about/procurement-contracts/chotatsu-index.html
# ハイパーリンクが張られている文: 東京大学ウェブアクセシビリティ方針
# URL:  /ja/general/webaccessibility.html
# ハイパーリンクが張られている文: 詳細を見る
# URL:  http://ep-monitor.adm.u-tokyo.ac.jp/denryoku
# ハイパーリンクが張られている文:
# URL:  https://www.facebook.com/UTokyo.News
# ハイパーリンクが張られている文:
# URL:  https://twitter.com/UTokyo_News
# ハイパーリンクが張られている文:
# URL:  https://www.youtube.com/user/UTokyoPR/
# ハイパーリンクが張られている文: ソーシャルメディア
# URL:  /ja/about/sns/list.html
# ハイパーリンクが張られている文:
# URL:  #content
# ハイパーリンクが張られている文:
# URL:  /focus/ja/articles/z0508_00039.html
# ハイパーリンクが張られている文: 東京大学災害時情報サイト
# URL:  https://blogs.yahoo.co.jp/utokyo_disasterinfo
# ハイパーリンクが張られている文: サイトマップ
# URL:  /ja/general/sitemap.html
# ハイパーリンクが張られている文: サイトポリシー
# URL:  /ja/general/policy.html
# ハイパーリンクが張られている文: プライバシーポリシー
# URL:  /ja/general/privacy_policy.html
# ハイパーリンクが張られている文: 採用情報
# URL:  /ja/about/jobs/index.html
# ハイパーリンクが張られている文: 学内NWから
# URL:  https://www.ut-portal.u-tokyo.ac.jp/gakunai/
# ハイパーリンクが張られている文: 学外NWから
# URL:  /adm/dics/ja/gateway.html
# ハイパーリンクが張られている文: よくある質問
# URL:  /ja/general/qa.html
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  #map
# ハイパーリンクが張られている文: 柏キャンパス
# URL:  #map1
# ハイパーリンクが張られている文: 本郷キャンパス
# URL:  #map2
# ハイパーリンクが張られている文: 駒場キャンパス
# URL:  #map3
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html
# ハイパーリンクが張られている文: 閉じる
# URL:  #
# ハイパーリンクが張られている文: 戻る
# URL:  #map
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html#kashiwa
# ハイパーリンクが張られている文: 閉じる
# URL:  #
# ハイパーリンクが張られている文: 戻る
# URL:  #map
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html#hongo
# ハイパーリンクが張られている文: 閉じる
# URL:  #
# ハイパーリンクが張られている文: 戻る
# URL:  #map
# ハイパーリンクが張られている文: アクセス・キャンパスマップ
# URL:  /ja/about/campus-guide/index.html#komaba
# ハイパーリンクが張られている文: 閉じる
# URL:  #

# %% [markdown]
# ## 2.4 find_allに複数条件の指定
# `find_all`では複数の条件を指定することもできます。
# 例えば、東京大学のホームページのニュースコーナー「UTokyo FOCUS」は次のような書式で書かれています。
#
# ```
# <div class="p-slider-pc">
#     <div><a href="/focus/ja/features/voices069.html"><img src="/content/400119832.jpg" alt="">
#         <div class="p-slider-msg">
#             <div class="p-slider-msg-inner">UTOKYO VOICES<br>光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。</div>
#         </div>
#     </a></div>
#     <div><a href="/opendays/index.html"><img src="/content/400119155.jpg" alt="">
#         <div class="p-slider-msg">
#             <div class="p-slider-msg-inner">「高校生のためのオープンキャンパス2019」<br>2019年8月7日(水)･ 8日(木)に実施します。</div>
#         </div>
#     </a></div>
# </div>
# ```
#
# つまり、タグが`div`、クラスが`p-slider-pc`でマークアップされたものの中の、
# タグが`div`、クラスが`p-slider-msg-inner`でマークアップされたテキストが一つの「UTokyo FOCUS」ということになります。
# よって、「UTokyo FOCUS」のテキスト一覧は以下のようにして取得することができます。

# %%
for div1 in soup.find_all('div', attrs={"class": "p-slider-pc"}):
    for div2 in div1.find_all('div', attrs={"class": "p-slider-msg"}):
        print(div2.text.replace('\n', ''))

# こちらでもOK
#for div in soup.select(".p-slider-pc"):
#    for div2 in div.select('.p-slider-msg'): 
#        print(div2.text.replace('\n', ''))
# Out:
# FSIプロジェクトシリーズ国連の持続可能な開発目標（SDGs）に貢献する学内の研究活動を紹介していきます。
# UTOKYO VOICES光合成研究から次世代太陽電池の開発へ。光エネルギー変換にかけた35年。
# 「高校生のためのオープンキャンパス2019」2019年8月7日(水)･ 8日(木)に実施します。
# UTokyo FOCUS足立区と東大の｢おいしい｣関係
# キミの東大薬学研究は病気のメカニズム解明や創薬だけでなく、基礎生物学にも大きな影響を及ぼせる―薬学部・富田泰輔教授
# 東京大学広報誌「淡青」38号
# 東京カレッジ世界の研究者・知識人と新たな知を拓き、伝える。東京カレッジが始まります。

# %% [markdown]
# ## 2.5 画像のクロール
#
# 画像の場合は、`<img src="画像へのリンク", alt="画像が表示できなかった場合の代替テキスト">`となっているため、
# このページに貼られている画像のリストは以下のようにして取得できます。

# %%
for address in soup.find_all('img'):
    print('URL: ', address['src'])
    print('代替テキスト: ', address['alt'])
# Out:
# URL:  /content/400109180.jpg
# 代替テキスト:  東京大学
# URL:  /content/100075725.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100074616.jpg
# 代替テキスト:  UTokyo FOCUS
# URL:  /content/100116151.png
# 代替テキスト:  大学案内
# URL:  /content/100116153.png
# 代替テキスト:  学部・大学院等
# URL:  /content/100116109.png
# 代替テキスト:  入学案内
# URL:  /content/100116116.png
# 代替テキスト:  教育・学生生活
# URL:  /content/100116161.png
# 代替テキスト:  研究活動
# URL:  /content/100116132.png
# 代替テキスト:  社会連携
# URL:  /content/100116137.png
# 代替テキスト:  産学連携
# URL:  /content/100116078.png
# 代替テキスト:  国際交流
# URL:  /content/100116096.png
# 代替テキスト:  卒業生
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400119944.jpg
# 代替テキスト:
# URL:  /content/400119832.jpg
# 代替テキスト:
# URL:  /content/400119155.jpg
# 代替テキスト:
# URL:  /content/400118046.jpg
# 代替テキスト:
# URL:  /content/400117191.jpg
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400110613.jpg
# 代替テキスト:
# URL:  /content/400109797.jpg
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400119944.jpg
# 代替テキスト:
# URL:  /content/400119832.jpg
# 代替テキスト:
# URL:  /content/400119155.jpg
# 代替テキスト:
# URL:  /content/400118046.jpg
# 代替テキスト:
# URL:  /content/400117191.jpg
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400110613.jpg
# 代替テキスト:
# URL:  /content/400109797.jpg
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400088131.png
# 代替テキスト:
# URL:  /content/400117278.jpg
# 代替テキスト:
# URL:  /content/400119211.jpg
# 代替テキスト:
# URL:  /content/100074697.jpg
# 代替テキスト:
# URL:  /content/100074625.png
# 代替テキスト:
# URL:  /content/100074624.png
# 代替テキスト:
# URL:  /content/100074625.png
# 代替テキスト:
# URL:  /content/400094844.png
# 代替テキスト:
# URL:  /content/400094843.jpg
# 代替テキスト:
# URL:  /content/400088087.jpg
# 代替テキスト:
# URL:  /content/400101527.jpg
# 代替テキスト:
# URL:  /content/400088097.jpg
# 代替テキスト:
# URL:  /content/400092280.png
# 代替テキスト:
# URL:  /content/400088091.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400088090.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400088089.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400088088.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400092281.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400092481.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400092282.jpg
# 代替テキスト:
# URL:  /content/400088093.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400088094.jpg
# 代替テキスト:
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400106907.jpg
# 代替テキスト:
# URL:  /content/400112267.jpg
# 代替テキスト:  白い表紙にベージュの模様
# URL:  /content/400115014.png
# 代替テキスト:  Movie
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/400007620.gif
# 代替テキスト:  1
# URL:  /content/400007619.gif
# 代替テキスト:  2
# URL:  /content/400007619.gif
# 代替テキスト:  3
# URL:  /content/400007662.gif
# 代替テキスト:
# URL:  /content/400007624.gif
# 代替テキスト:  00:00-00:59
# URL:  /content/400007621.gif
# 代替テキスト:  0
# URL:  /content/400007621.gif
# 代替テキスト:  1
# URL:  /content/400007621.gif
# 代替テキスト:  2
# URL:  /content/400007622.gif
# 代替テキスト:
# URL:  /content/400007621.gif
# 代替テキスト:  3
# URL:  /content/400007621.gif
# 代替テキスト:  4
# URL:  /content/400007621.gif
# 代替テキスト:  5
# URL:  /content/100074653.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100074629.jpg
# 代替テキスト:  Facebook（別ウィンドウで開く）
# URL:  /content/100074651.jpg
# 代替テキスト:  Twitter（別ウィンドウで開く）
# URL:  /content/100074655.jpg
# 代替テキスト:  Youtube（別ウィンドウで開く）
# URL:  /content/100074660.jpg
# 代替テキスト:  ページTOPに戻る
# URL:  /content/400109180.jpg
# 代替テキスト:  東京大学
# URL:  /content/100075725.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100075725.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100075725.png
# 代替テキスト:  別ウィンドウで開く
# URL:  /content/100097951.jpg
# 代替テキスト:  アクセス・キャンパスマップ
# URL:  /content/100097954.jpg
# 代替テキスト:  柏キャンパス
# URL:  /content/100097952.jpg
# 代替テキスト:  本郷キャンパス
# URL:  /content/100097953.jpg
# 代替テキスト:  駒場キャンパス

# %% [markdown]
# なお、画像へのリンクは、多くの場合、絶対アドレスではなく相対アドレスで指定されていることに注意してください。
# 画像のリンク先に置かれている画像をとってきたい場合は、いまアクセスしているURLを相対アドレスの前につなげる必要があります。

# %%
# `img`タグの情報を一つだけとってきます
address = soup.find('img')
print('画像ファイルのアドレス: ', address['src'])

# もしその'src'に'http'という文字列が含まれていないならば、
# それは相対アドレスなので、このページのURLを前につなげます
if 'http' not in address['src']:
    abs_address = 'https://www.u-tokyo.ac.jp/' + address['src']    
    print('画像ファイルの絶対アドレス: ', abs_address)
    
    # この教材の冒頭で使用したrequetsを使って画像ファイルをダウンロードしましょう
    r = requests.get(abs_address, stream=True)
    
    # 無事ダウンロードに成功したら、'img'という名前のフォルダの下に保存しましょう
    if r.status_code == 200:
        fname = 'img/' + abs_address.split('/')[-1]
        print('画像の保存先: ', fname)
        with open(fname, 'wb') as f:
            f.write(r.content)    
    else:
        print('画像の保存に失敗しました。')
# Out:
# 画像ファイルのアドレス:  /content/400109180.jpg
# 画像ファイルの絶対アドレス:  https://www.u-tokyo.ac.jp//content/400109180.jpg
# 画像の保存先:  img/400109180.jpg

# %% [markdown]
# ダウンロードした画像は、この教材がおかれているフォルダの中にある`img`という名前のフォルダの中に置かれているはずです。
# 確認してみてください。
#
# HTMLでは他にも様々なタグが使われます。
# タグの種類や意味は[ここ](http://www.htmq.com/html/indexm.shtml)を参照してください。
# なお、HTMLソースのタグは大文字・小文字を区別しません。

# %% [markdown]
# Beautiful Soupにはほかにも様々なパラメータが用意されています。
# 詳しくは[こちらのドキュメント](http://kondou.com/BS4/)を参照してください。
