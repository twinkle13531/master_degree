# %%
# !pwd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append(os.path.join('..', '..', '..', 'functions'))

# %%
import pandas as pd
import numpy as np
import markov_basis_make_samples as mbms

# %% [markdown]
# ### 35bit

# %%
bit = 35

# %% [markdown]
# ## random method

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('20bit_', num, ' data can make ', len(ms.random(10000)), 'samples using markov basis and random method')
# Out:
# 20bit_ 0  data can make  3335 samples using markov basis and random method
# 20bit_ 1  data can make  3988 samples using markov basis and random method
# 20bit_ 2  data can make  3837 samples using markov basis and random method
# 20bit_ 3  data can make  3605 samples using markov basis and random method
# 20bit_ 4  data can make  3065 samples using markov basis and random method

# %%
print('i knew that 20bit data can make ', (3335+3988+3837+3605+3065)/5, 'samples using markov basis and random method.')
# Out:
# i knew that 20bit data can make  3566.0 samples using markov basis and random method.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/random_10000_t_num".format(num)
    hist_dic = mbms.y_num_t1_hist(df, ms.random(10000), plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    print('p values is',mbms.p_value(df, ms.random(10000)) , 'when i use 20bit_', num, ' data markov basis and random method')
# Out:
# p values is 0.061817046518888544 when i use 20bit_ 0  data markov basis and random method
# p values is 0.06717557251908397 when i use 20bit_ 1  data markov basis and random method
# p values is 0.08821170809943865 when i use 20bit_ 2  data markov basis and random method
# p values is 0.2647374062165059 when i use 20bit_ 3  data markov basis and random method
# p values is 0.06920199501246883 when i use 20bit_ 4  data markov basis and random method

# %%
mean_p = (0.061817046518888544+0.06717557251908397+0.08821170809943865+0.2647374062165059+0.06920199501246883)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and random method.')
# Out:
# i knew that mean p values of 20bit dat is 0.11022874567327719 when i use markov basis and random method.

# %% [markdown]
# ## SA

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('20bit_', num, ' data can make ', len(valid_y), 'samples using markov basis and SA')
# Out:
# 20bit_ 0  data can make  1689 samples using markov basis and SA
# 20bit_ 1  data can make  1970 samples using markov basis and SA
# 20bit_ 2  data can make  1958 samples using markov basis and SA
# 20bit_ 3  data can make  1766 samples using markov basis and SA
# 20bit_ 4  data can make  1679 samples using markov basis and SA

# %%
print('i knew that 20bit data can make ', (1689+1970+1958+1766+1689)/5, 'samples using markov basis and SA.')
# Out:
# i knew that 20bit data can make  1814.4 samples using markov basis and SA.

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    plot_path = "{}/SA_10000_t_num".format(num)
    E_list, valid_y = ms.SA(10000)
    hist_dic = mbms.y_num_t1_hist(df, valid_y, plot_path)

# %%
for num in [0, 1, 2, 3, 4]:
    df_path = '../../../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    matmar_path = '../../../{}bit/{}/{}bit_{}.mat.mar'.format(bit, num, bit, num)
    result_list = mbms.make_result_list(matmar_path)
    ms = mbms.make_samples_using_markov_basis(df, matmar_path, result_list)
    E_list, valid_y = ms.SA(10000)
    print('p values is',mbms.p_value(df, valid_y) , 'when i use 20bit_', num, ' data markov basis and SA')
# Out:
# p values is 0.07142857142857142 when i use 20bit_ 0  data markov basis and SA
# p values is 0.043343653250773995 when i use 20bit_ 1  data markov basis and SA
# p values is 0.06684491978609626 when i use 20bit_ 2  data markov basis and SA
# p values is 0.41103965702036444 when i use 20bit_ 3  data markov basis and SA
# p values is 0.12208588957055215 when i use 20bit_ 4  data markov basis and SA

# %%
mean_p = (0.07142857142857142+0.043343653250773995+0.06684491978609626+0.41103965702036444+0.12208588957055215)/5
print('i knew that mean p values of 20bit dat is', mean_p, 'when i use markov basis and SA.')
# Out:
# i knew that mean p values of 20bit dat is 0.14294853821127165 when i use markov basis and SA.
