# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/Random/20bit/0

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
sys.path.append(os.path.join('..', '..'))

# %%
import random_exact_test_functions as ret
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt

# %%
bit = 20
num = 0

# %%
num_reads=10000

# %%
df_path = '../../../input/ost{}_{}.csv'.format(bit, num)
df = pd.read_csv(df_path, sep=',')

# %%
t_list = ret.calc_marginals(df)
valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)

# %%
rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)

# %%
plot_path = 'Random_{}bit_{}_10000_y_num_t1'.format(bit, num)
t_tic = rm.y_num_t1_hist(plot_path)

# %%
output_path = 'Random_{}bit_{}_10000_p_value_transition'.format(bit, num)
p_dic = rm.p_value_transition(output_path)

# %%
path = 'Random_{}bit_{}_10000_time_num_y_transition'.format(bit, num)
valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)

# %%
loop = 10
result = timeit.timeit('ret.find_valid_y(df, num_reads)', globals=globals(), number=loop)
reads10000_time = result / loop
print(reads10000_time, '秒')
# Out:
# 0.19563959819999469 秒
