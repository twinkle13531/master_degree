# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202012/Random

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import random_exact_test_functions as ret
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt

# %%
num_reads=10000

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
            if valid_y_num >0:
                rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
                plot_path = '{}bit/{}/Random_{}bit_{}_10000_y_num_t1'.format(bit, num, bit, num)
                t_tic = rm.y_num_t1_hist(plot_path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
        if valid_y_num >0:
            rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
            plot_path = '{}bit/Random_{}bit_10000_y_num_t1'.format(bit, bit)
            t_tic = rm.y_num_t1_hist(plot_path)

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
            if valid_y_num >0:
                rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
                output_path = '{}bit/{}/Random_{}bit_{}_10000_p_value_transition'.format(bit, num, bit, num)
                p_dic = rm.p_value_transition(output_path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
        if valid_y_num >0:
            rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
            output_path = '{}bit/Random_{}bit_10000_p_value_transition'.format(bit, bit)
            p_dic = rm.p_value_transition(output_path)

# %%
for bit in [20, 25, 30, 35, 40, 46]:
    if bit != 46:
        for num in [0, 1, 2, 3, 4]:
            df_path = '../input/ost{}_{}.csv'.format(bit, num)
            df = pd.read_csv(df_path, sep=',')
            t_list = ret.calc_marginals(df)
            valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
            rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
            path = '{}bit/{}/Random_{}bit_{}_10000_time_num_y_transition'.format(bit, num, bit, num)
            valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)
    else:
        df_path = '../input/ost{}.csv'.format(bit)
        df = pd.read_csv(df_path, sep=',')
        t_list = ret.calc_marginals(df)
        valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
        rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
        path = '{}bit/Random_{}bit_10000_time_num_y_transition'.format(bit, bit)
        valid_ys, time_list, valid_y_number = rm.time_num_y_transition(path)

# %%
y_num_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    y_num_list.append(valid_y_num)
    print('number of valid y of {}bit_{} data is {}'.format(bit, num, y_num_list[-1]))
print('mean number of valid y of {}bit data is {}'.format(bit, sum(y_num_list)/5))
# Out:
# number of valid y of 20bit_0 data is 165
# number of valid y of 20bit_1 data is 32
# number of valid y of 20bit_2 data is 9
# number of valid y of 20bit_3 data is 22
# number of valid y of 20bit_4 data is 15
# mean number of valid y of 20bit data is 48.6

# %%
p_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    t_list = ret.calc_marginals(df)
    valid_y_list, valid_y_num = ret.find_valid_y(df, num_reads)
    rm = ret.Random_method(df, valid_y_list, valid_y_num, num_reads, t_list)
    p_list.append(rm.p_value())
    print('p value of {}bit_{} data is {}'.format(bit, num, p_list[-1]))
print('mean p value of {}bit data is {}'.format(bit, sum(p_list)/5))
# Out:
# p value of 20bit_0 data is 0.2573099415204678
# p value of 20bit_1 data is 0.4
# p value of 20bit_2 data is 0.5833333333333334
# p value of 20bit_3 data is 0.4482758620689655
# p value of 20bit_4 data is 0.30434782608695654
# mean p value of 20bit data is 0.39865339260194466

# %%
time_list = []
for num in [0, 1, 2, 3, 4]:
    df_path = '../../input/ost{}_{}.csv'.format(bit, num)
    df = pd.read_csv(df_path, sep=',')
    loop = 10
    result = timeit.timeit('ret.find_valid_y(df, num_reads)', globals=globals(), number=loop)
    time_list.append(result/loop)
    print('calucuration time of {}bit_{} data is {}'.format(bit, num, time_list[-1]))
print('mean calucuration time of {}bit data is {}'.format(bit, sum(time_list)/5))
# Out:
# calucuration time of 20bit_0 data is 0.18552691740005683
# calucuration time of 20bit_1 data is 0.0709505495000485
# calucuration time of 20bit_2 data is 0.06933074559992747
# calucuration time of 20bit_3 data is 0.18460488030004854
# calucuration time of 20bit_4 data is 0.18051538510007958
# mean calucuration time of 20bit data is 0.1381856955800322
