# %% [markdown]
# 1. NN

# %%
import pandas as pd

data_SNP = pd.read_table('CIMMYTwheat_markers.txt', header=None,  sep =  ' ')


# 目的変数
data_yields = pd.read_table('CIMMYTwheat_yields.txt', header=None,  sep =  ' ')

#１列目での予測失敗、最大値を使った予測失敗、最小値を使った予測失敗、2・3列目での予測失敗
data_amount_list = []
for i in range(len(data_yields)):
    data_amount_list.append(data_yields.iloc[i, 0])

data_amount = pd.Series(data_amount_list)

from sklearn.model_selection import train_test_split
x_train, x_test, t_train, t_test = train_test_split(data_SNP, data_amount, test_size=0.3)

# %%
import numpy as np

# affine変換
def affine(z, W, b):
    return np.dot(z, W) + b

# affine変換勾配
def affine_back(du, z, W, b):
    dz = np.dot(du, W.T)
    dW = np.dot(z.T, du)
    db = np.dot(np.ones(z.shape[0]).T, du)
    return dz, dW, db

# 活性化関数(ReLU)
def relu(u):
    return np.maximum(0, u)

# 活性化関数(ReLU)勾配
def relu_back(dz, u):
    return dz * np.where(u > 0, 1, 0)

# 活性化関数(恒等関数)
def koutou(u):
    return u

# 誤差(平均二乗誤差）
def mean_sequared_error(y, t):
    return 0.5*np.sum((y-t)**2)

# 誤差(平均二乗誤差）＋活性化関数(恒等関数)勾配
def koutou_mean_sequared_error_back(y, t):
    return y - t


# 要素を1次元の配列に並べる
def flatten(x):
    return x.reshape((-1))

# %%
def learn(x, t, W1, b1, W2, b2, W3, b3, lr):
    # 順伝播
    u1 = affine(x, W1, b1)
    z1 = relu(u1)
    u2 = affine(z1, W2, b2)
    z2 = relu(u2)
    u3 = affine(z2, W3, b3)
    y  = flatten(koutou(u3))
    # 逆伝播
    dy = np.expand_dims(koutou_mean_sequared_error_back(y, t), axis=1)
    dz2, dW3, db3 = affine_back(dy, z2, W3, b3)
    du2 = relu_back(dz2, u2)
    dz1, dW2, db2 = affine_back(du2, z1, W2, b2)
    du1 = relu_back(dz1, u1)
    dx, dW1, db1 = affine_back(du1, x, W1, b1)
    # 重み、バイアスの更新
    W1 = W1 - lr * dW1
    b1 = b1 - lr * db1
    W2 = W2 - lr * dW2
    b2 = b2 - lr * db2
    W3 = W3 - lr * dW3
    b3 = b3 - lr * db3

    return W1, b1, W2, b2, W3, b3

# %%
def predict(x, W1, b1, W2, b2, W3, b3):
    # 順伝播
    u1 = affine(x, W1, b1)
    z1 = relu(u1)
    u2 = affine(z1, W2, b2)
    z2 = relu(u2)
    u3 = affine(z2, W3, b3)
    y  = koutou(u3)
    return flatten(y)

# %%
# 正解率
def accuracy_rate(y, t):
    max_y = np.argmax(y, axis=1)
    max_t = np.argmax(t, axis=1)
    return np.sum(max_y == max_t)/y.shape[0]

# %%
#.values.reshape((-1))

# %%
# ノード数設定
d0 = x_train.shape[1]
d1 = 100 # 1層目のノード数
d2 = 50  # 2層目のノード数
d3 = 1

# 重みの初期化(-0.1～0.1の乱数)
np.random.seed(8)
W1 = np.random.rand(d0, d1) * 0.2 - 0.1
W2 = np.random.rand(d1, d2) * 0.2 - 0.1
W3 = np.random.rand(d2, d3) * 0.2 - 0.1

# バイアスの初期化(0)
b1 = np.zeros(d1)
b2 = np.zeros(d2)
b3 = np.zeros(d3)

# 学習率
lr = 1e-4

# バッチサイズ
batch_size = 100

# 学習回数
epoch = 50

# 予測（学習データ）
y_train = predict(x_train, W1, b1, W2, b2, W3, b3)
# 予測（テストデータ）
y_test = predict(x_test, W1, b1, W2, b2, W3, b3)
# 正解率、誤差表示
train_rate, train_err = mean_sequared_error(y_train, t_train), mean_sequared_error(y_train, t_train)
test_rate, test_err = mean_sequared_error(y_test, t_test), mean_sequared_error(y_test, t_test)
print("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((0), train_rate*100, test_rate*100, train_err, test_err))
for i in range(epoch):
    # 学習
    for j in range(0, x_train.shape[0], batch_size):
        W1, b1, W2, b2, W3, b3 = learn(x_train[j:j+batch_size], t_train[j:j+batch_size].values.reshape((-1)), W1, b1, W2, b2, W3, b3, lr)
    # 予測（学習データ）
    y_train = predict(x_train, W1, b1, W2, b2, W3, b3)
    # 予測（テストデータ）
    y_test = predict(x_test, W1, b1, W2, b2, W3, b3)
    # 正解率、誤差表示
    train_rate, train_err = mean_sequared_error(y_train, t_train), mean_sequared_error(y_train, t_train)
    test_rate, test_err = mean_sequared_error(y_test, t_test), mean_sequared_error(y_test, t_test)
    print("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((i+1), train_rate*100, test_rate*100, train_err, test_err))
# Out:
#   0 train_rate=22954.48% test_rate=7234.33% train_err=229.54481 test_err=72.34326
#   1 train_rate=22867.51% test_rate=7202.84% train_err=228.67515 test_err=72.02836
#   2 train_rate=22788.26% test_rate=7178.00% train_err=227.88259 test_err=71.77999
#   3 train_rate=22712.44% test_rate=7156.15% train_err=227.12440 test_err=71.56151
#   4 train_rate=22639.99% test_rate=7137.69% train_err=226.39987 test_err=71.37693
#   5 train_rate=22566.51% test_rate=7121.22% train_err=225.66513 test_err=71.21224
#   6 train_rate=22493.42% test_rate=7105.17% train_err=224.93423 test_err=71.05173
#   7 train_rate=22419.29% test_rate=7088.27% train_err=224.19289 test_err=70.88274
#   8 train_rate=22345.16% test_rate=7071.90% train_err=223.45161 test_err=70.71902
#   9 train_rate=22273.83% test_rate=7055.59% train_err=222.73835 test_err=70.55591
#  10 train_rate=22203.74% test_rate=7040.14% train_err=222.03738 test_err=70.40140
#  11 train_rate=22132.24% test_rate=7025.08% train_err=221.32241 test_err=70.25084
#  12 train_rate=22060.20% test_rate=7010.79% train_err=220.60197 test_err=70.10789
#  13 train_rate=21988.32% test_rate=6996.80% train_err=219.88325 test_err=69.96800
#  14 train_rate=21917.04% test_rate=6982.59% train_err=219.17043 test_err=69.82591
#  15 train_rate=21845.63% test_rate=6968.70% train_err=218.45631 test_err=69.68704
#  16 train_rate=21774.03% test_rate=6954.67% train_err=217.74026 test_err=69.54669
#  17 train_rate=21700.53% test_rate=6940.80% train_err=217.00526 test_err=69.40804
#  18 train_rate=21626.06% test_rate=6927.07% train_err=216.26060 test_err=69.27074
#  19 train_rate=21549.41% test_rate=6912.90% train_err=215.49412 test_err=69.12897
#  20 train_rate=21470.54% test_rate=6898.59% train_err=214.70541 test_err=68.98594
#  21 train_rate=21389.12% test_rate=6885.10% train_err=213.89119 test_err=68.85103
#  22 train_rate=21304.87% test_rate=6872.50% train_err=213.04873 test_err=68.72501
#  23 train_rate=21217.85% test_rate=6859.98% train_err=212.17850 test_err=68.59984
#  24 train_rate=21129.71% test_rate=6848.36% train_err=211.29709 test_err=68.48359
#  25 train_rate=21039.42% test_rate=6836.81% train_err=210.39420 test_err=68.36814
#  26 train_rate=20946.43% test_rate=6826.07% train_err=209.46428 test_err=68.26072
#  27 train_rate=20851.21% test_rate=6816.25% train_err=208.51213 test_err=68.16245
#  28 train_rate=20754.09% test_rate=6806.12% train_err=207.54085 test_err=68.06119
#  29 train_rate=20655.36% test_rate=6796.54% train_err=206.55360 test_err=67.96540
#  30 train_rate=20555.57% test_rate=6787.52% train_err=205.55568 test_err=67.87518
#  31 train_rate=20453.80% test_rate=6779.67% train_err=204.53796 test_err=67.79665
#  32 train_rate=20349.97% test_rate=6771.63% train_err=203.49965 test_err=67.71630
#  33 train_rate=20243.73% test_rate=6763.99% train_err=202.43730 test_err=67.63992
#  34 train_rate=20134.78% test_rate=6756.71% train_err=201.34780 test_err=67.56707
#  35 train_rate=20022.55% test_rate=6750.46% train_err=200.22551 test_err=67.50456
#  36 train_rate=19908.16% test_rate=6745.46% train_err=199.08165 test_err=67.45456
#  37 train_rate=19789.33% test_rate=6741.21% train_err=197.89328 test_err=67.41213
#  38 train_rate=19668.52% test_rate=6737.25% train_err=196.68523 test_err=67.37250
#  39 train_rate=19548.20% test_rate=6732.82% train_err=195.48204 test_err=67.32824
#  40 train_rate=19428.18% test_rate=6729.03% train_err=194.28176 test_err=67.29027
#  41 train_rate=19306.20% test_rate=6726.75% train_err=193.06197 test_err=67.26753
#  42 train_rate=19182.72% test_rate=6724.05% train_err=191.82723 test_err=67.24054
#  43 train_rate=19058.16% test_rate=6721.79% train_err=190.58162 test_err=67.21789
#  44 train_rate=18933.11% test_rate=6719.46% train_err=189.33108 test_err=67.19455
#  45 train_rate=18806.24% test_rate=6718.83% train_err=188.06235 test_err=67.18832
#  46 train_rate=18677.47% test_rate=6717.84% train_err=186.77472 test_err=67.17845
#  47 train_rate=18547.87% test_rate=6718.44% train_err=185.47873 test_err=67.18444
#  48 train_rate=18415.72% test_rate=6719.99% train_err=184.15717 test_err=67.19991
#  49 train_rate=18281.85% test_rate=6721.68% train_err=182.81851 test_err=67.21681
#  50 train_rate=18144.42% test_rate=6723.51% train_err=181.44415 test_err=67.23513

# %%
'''
# ノード数設定
d0 = x_train.shape[1]
d1 = 100 # 1層目のノード数
d2 = 50  # 2層目のノード数
d3 = 10

# 重みの初期化(-0.1～0.1の乱数)
np.random.seed(8)
W1 = np.random.rand(d0, d1) * 0.2 - 0.1
W2 = np.random.rand(d1, d2) * 0.2 - 0.1
W3 = np.random.rand(d2, d3) * 0.2 - 0.1

# バイアスの初期化(0)
b1 = np.zeros(d1)
b2 = np.zeros(d2)
b3 = np.zeros(d3)

# 学習率
lr = 0.5

# バッチサイズ
batch_size = 100

# 学習回数
epoch = 50

# 予測（学習データ）
y_train = predict(x_train, W1, b1, W2, b2, W3, b3)

# 予測（テストデータ）
y_test = predict(x_test, W1, b1, W2, b2, W3, b3)

# 正解率、誤差表示
train_rate, train_err = accuracy_rate(y_train, t_train), mean_sequared_error(y_train, t_train)
test_rate, test_err = accuracy_rate(y_test, t_test), mean_sequared_error(y_test, t_test)
print("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((0), train_rate*100, test_rate*100, train_err, test_err))

for i in range(epoch):
    # 学習
    for j in range(0, x_train.shape[0], batch_size):
        W1, b1, W2, b2, W3, b3 = learn(x_train[j:j+batch_size], t_train[j:j+batch_size], W1, b1, W2, b2, W3, b3, lr)

    # 予測（学習データ）
    y_train = predict(x_train, W1, b1, W2, b2, W3, b3)
    # 予測（テストデータ）
    y_test = predict(x_test, W1, b1, W2, b2, W3, b3)
    # 正解率、誤差表示
    train_rate, train_err = accuracy_rate(y_train, t_train), mean_sequared_error(y_train, t_train)
    test_rate, test_err = accuracy_rate(y_test, t_test), mean_sequared_error(y_test, t_test)
    print("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((i+1), train_rate*100, test_rate*100, train_err, test_err))
'''
# Out:
# '\n# ノード数設定\nd0 = x_train.shape[1]\nd1 = 100 # 1層目のノード数\nd2 = 50  # 2層目のノード数\nd3 = 10\n\n# 重みの初期化(-0.1～0.1の乱数)\nnp.random.seed(8)\nW1 = np.random.rand(d0, d1) * 0.2 - 0.1\nW2 = np.random.rand(d1, d2) * 0.2 - 0.1\nW3 = np.random.rand(d2, d3) * 0.2 - 0.1\n\n# バイアスの初期化(0)\nb1 = np.zeros(d1)\nb2 = np.zeros(d2)\nb3 = np.zeros(d3)\n\n# 学習率\nlr = 0.5\n\n# バッチサイズ\nbatch_size = 100\n\n# 学習回数\nepoch = 50\n\n# 予測（学習データ）\ny_train = predict(x_train, W1, b1, W2, b2, W3, b3)\n\n# 予測（テストデータ）\ny_test = predict(x_test, W1, b1, W2, b2, W3, b3)\n\n# 正解率、誤差表示\ntrain_rate, train_err = accuracy_rate(y_train, t_train), mean_sequared_error(y_train, t_train)\ntest_rate, test_err = accuracy_rate(y_test, t_test), mean_sequared_error(y_test, t_test)\nprint("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((0), train_rate*100, test_rate*100, train_err, test_err))\n\nfor i in range(epoch):\n    # 学習\n    for j in range(0, x_train.shape[0], batch_size):\n        W1, b1, W2, b2, W3, b3 = learn(x_train[j:j+batch_size], t_train[j:j+batch_size], W1, b1, W2, b2, W3, b3, lr)\n\n    # 予測（学習データ）\n    y_train = predict(x_train, W1, b1, W2, b2, W3, b3)\n    # 予測（テストデータ）\n    y_test = predict(x_test, W1, b1, W2, b2, W3, b3)\n    # 正解率、誤差表示\n    train_rate, train_err = accuracy_rate(y_train, t_train), mean_sequared_error(y_train, t_train)\n    test_rate, test_err = accuracy_rate(y_test, t_test), mean_sequared_error(y_test, t_test)\n    print("{0:3d} train_rate={1:6.2f}% test_rate={2:6.2f}% train_err={3:8.5f} test_err={4:8.5f}".format((i+1), train_rate*100, test_rate*100, train_err, test_err))\n'

# %% [markdown]
# 1. 結果
#
# 線形回帰だけでなくNNでも予測がうまくできなかった
