# %%
# !pwd
# Out:
# /Users/shihosato/src/github.com/twinkle13531/master_degree/202011/scripts/trials/Summary

# %%
# %run ../../functions/Neal_exact_test_functions.ipynb

# %% [markdown]
# ## 20bit data

# %%
df = pd.read_csv('../../../input/ost20.csv', sep=',', index_col=0)
print('20 bit datasets t_list:', calc_marginals(df))
# Out:
# 20 bit datasets t_list: [12 10  6]

# %%
t1 = np.dot(df['Y'], df['LI'])
print('20 bit datasets t1 is {}'.format(t1))
# Out:
# 20 bit datasets t1 is 9

# %%
2**20
# Out:
# 1048576

# %%
neal_y_list, neal_y_num_list, neal_time_list = time_num_y(
    df, num_reads=10000, 
    path='../../../output/nealSA_20bit_10000numreads_num_time_transition'
)

# %%
_4ti2_20bit_hits = 5292
_4ti2_20bit_total_time = 0.63

x_4ti2 = np.linspace(0,_4ti2_20bit_total_time, _4ti2_20bit_hits)

# 直線の式を定義
y_4ti2 = [i for i in range(_4ti2_20bit_hits)]

# 直線をプロット
#ax.plot(x, y, color = "red")

# %%
random_20bit_hits = 54
random_20bit_total_time = 0.2017250026 

x_random = np.linspace(0,random_20bit_total_time, random_20bit_hits)

# 直線の式を定義
y_random = [i for i in range(random_20bit_hits)]

# %%
plt.xlabel('time')
plt.ylabel('number of hits')
plt.plot(neal_time_list, neal_y_num_list, color = 'blue')
plt.plot(x_4ti2, y_4ti2, color = 'red')
plt.plot(x_random, y_random, color = 'green')
plt.savefig('../../../output/comparision_20bit_10000numreads_num_time')
plt.show()
